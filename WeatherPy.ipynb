# %%
# Move this file to Homework folder into Weather_Analysis and git add, commit, push

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
#  Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | nome
# Processing Record 4 of Set 1 | kattivakkam
# Processing Record 5 of Set 1 | kitui
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | zalantun
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | galchino
# City not found. Skipping...
# Processing Record 10 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | marv dasht
# City not found. Skipping...
# Processing Record 13 of Set 1 | villazon
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | axim
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 20 of Set 1 | yerbogachen
# Processing Record 21 of Set 1 | tombouctou
# Processing Record 22 of Set 1 | kruisfontein
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | purpe
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | maryborough
# Processing Record 28 of Set 1 | kaputa
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | hambantota
# Processing Record 31 of Set 1 | rosetta
# Processing Record 32 of Set 1 | noumea
# Processing Record 33 of Set 1 | asau
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | imeni poliny osipenko
# Processing Record 36 of Set 1 | kerki
# City not found. Skipping...
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | tilichiki
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | arifwala
# Processing Record 47 of Set 1 | coahuayana
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | narsaq
# Processing Record 50 of Set 1 | dawlatabad
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | nizhnyaya tavda
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | saint-pierre
# Processing Record 5 of Set 2 | tezu
# Processing Record 6 of Set 2 | kirakira
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | luhyny
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | lac du bonnet
# Processing Record 13 of Set 2 | namibe
# Processing Record 14 of Set 2 | virginia beach
# Processing Record 15 of Set 2 | coquimbo
# Processing Record 16 of Set 2 | atherton
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | nouadhibou
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | puerto baquerizo moreno
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | la ronge
# Processing Record 23 of Set 2 | humaita
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 2 | vostok
# Processing Record 27 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 2 | candido mendes
# Processing Record 31 of Set 2 | avera
# Processing Record 32 of Set 2 | taoudenni
# Processing Record 33 of Set 2 | bengkulu
# Processing Record 34 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | mantua
# Processing Record 37 of Set 2 | burnie
# Processing Record 38 of Set 2 | salalah
# Processing Record 39 of Set 2 | kangaatsiaq
# Processing Record 40 of Set 2 | kyra
# Processing Record 41 of Set 2 | port augusta
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | saint anthony
# Processing Record 45 of Set 2 | rabo de peixe
# Processing Record 46 of Set 2 | oksfjord
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | cherskiy
# Processing Record 49 of Set 2 | peterhead
# Processing Record 50 of Set 2 | mount darwin
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | zhangye
# Processing Record 4 of Set 3 | weinan
# Processing Record 5 of Set 3 | ust-koksa
# Processing Record 6 of Set 3 | tual
# Processing Record 7 of Set 3 | ixtapa
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | hervey bay
# Processing Record 10 of Set 3 | isangel
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | alekseyevsk
# Processing Record 13 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 3 | makakilo city
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | aykhal
# Processing Record 17 of Set 3 | lavrentiya
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | marienburg
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | keti bandar
# Processing Record 23 of Set 3 | jomalig
# City not found. Skipping...
# Processing Record 24 of Set 3 | strezhevoy
# Processing Record 25 of Set 3 | nioro
# Processing Record 26 of Set 3 | namatanai
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | kharan
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 3 | dicabisagan
# Processing Record 39 of Set 3 | takoradi
# Processing Record 40 of Set 3 | vindeby
# Processing Record 41 of Set 3 | vila franca do campo
# Processing Record 42 of Set 3 | lagoa
# Processing Record 43 of Set 3 | wanning
# Processing Record 44 of Set 3 | vasylivka
# Processing Record 45 of Set 3 | seddon
# Processing Record 46 of Set 3 | yarmouth
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | cockburn town
# Processing Record 49 of Set 3 | tupik
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | akcaabat
# Processing Record 2 of Set 4 | hermanus
# Processing Record 3 of Set 4 | puerto cabello
# Processing Record 4 of Set 4 | isparta
# Processing Record 5 of Set 4 | berdigestyakh
# Processing Record 6 of Set 4 | kastamonu
# Processing Record 7 of Set 4 | beruwala
# Processing Record 8 of Set 4 | baykit
# Processing Record 9 of Set 4 | baruun-urt
# Processing Record 10 of Set 4 | meulaboh
# Processing Record 11 of Set 4 | viedma
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | mayo
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | sao felix do xingu
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | tazovskiy
# Processing Record 19 of Set 4 | belyy yar
# Processing Record 20 of Set 4 | tillabery
# City not found. Skipping...
# Processing Record 21 of Set 4 | evensk
# Processing Record 22 of Set 4 | ulaangom
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | oranjemund
# Processing Record 25 of Set 4 | moose factory
# Processing Record 26 of Set 4 | najran
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | kitimat
# Processing Record 29 of Set 4 | dukat
# Processing Record 30 of Set 4 | ucluelet
# Processing Record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | okhotsk
# Processing Record 33 of Set 4 | san cristobal
# Processing Record 34 of Set 4 | dakar
# Processing Record 35 of Set 4 | amazar
# Processing Record 36 of Set 4 | bubaque
# Processing Record 37 of Set 4 | north branch
# Processing Record 38 of Set 4 | klaksvik
# Processing Record 39 of Set 4 | yellowknife
# Processing Record 40 of Set 4 | poum
# Processing Record 41 of Set 4 | touros
# Processing Record 42 of Set 4 | umm lajj
# Processing Record 43 of Set 4 | chokwe
# Processing Record 44 of Set 4 | charters towers
# Processing Record 45 of Set 4 | saquarema
# Processing Record 46 of Set 4 | hauterive
# Processing Record 47 of Set 4 | tessalit
# Processing Record 48 of Set 4 | mount isa
# Processing Record 49 of Set 4 | karratha
# Processing Record 50 of Set 4 | mount gambier
# Processing Record 1 of Set 5 | sao filipe
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | domoni
# Processing Record 4 of Set 5 | saint george
# Processing Record 5 of Set 5 | lesnoye
# Processing Record 6 of Set 5 | saint-joseph
# Processing Record 7 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 5 | yumen
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | lima
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | lorengau
# Processing Record 15 of Set 5 | dingle
# Processing Record 16 of Set 5 | rokycany
# Processing Record 17 of Set 5 | clyde river
# Processing Record 18 of Set 5 | pisco
# Processing Record 19 of Set 5 | chokurdakh
# Processing Record 20 of Set 5 | butaritari
# Processing Record 21 of Set 5 | adrar
# Processing Record 22 of Set 5 | amalapuram
# Processing Record 23 of Set 5 | butembo
# Processing Record 24 of Set 5 | muros
# Processing Record 25 of Set 5 | aban
# Processing Record 26 of Set 5 | bay roberts
# Processing Record 27 of Set 5 | yeniseysk
# Processing Record 28 of Set 5 | verkhoshizhemye
# Processing Record 29 of Set 5 | sicuani
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | dubenskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | diamantino
# Processing Record 33 of Set 5 | beringovskiy
# Processing Record 34 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | onega
# Processing Record 38 of Set 5 | tvedestrand
# Processing Record 39 of Set 5 | marawi
# Processing Record 40 of Set 5 | laguna
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | maralal
# Processing Record 43 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 5 | ndele
# Processing Record 45 of Set 5 | paracatu
# Processing Record 46 of Set 5 | verkhoyansk
# Processing Record 47 of Set 5 | port hardy
# Processing Record 48 of Set 5 | orange walk
# Processing Record 49 of Set 5 | nemuro
# Processing Record 50 of Set 5 | ulaanbaatar
# Processing Record 1 of Set 6 | yulara
# Processing Record 2 of Set 6 | matay
# Processing Record 3 of Set 6 | bilma
# Processing Record 4 of Set 6 | llangefni
# Processing Record 5 of Set 6 | palmer
# Processing Record 6 of Set 6 | santiago de cao
# Processing Record 7 of Set 6 | salinopolis
# Processing Record 8 of Set 6 | faya
# Processing Record 9 of Set 6 | avdon
# Processing Record 10 of Set 6 | sept-iles
# Processing Record 11 of Set 6 | kurikka
# Processing Record 12 of Set 6 | broken hill
# Processing Record 13 of Set 6 | dikson
# Processing Record 14 of Set 6 | vao
# Processing Record 15 of Set 6 | sinnamary
# Processing Record 16 of Set 6 | polyarnyy
# Processing Record 17 of Set 6 | paoua
# Processing Record 18 of Set 6 | miracema do tocantins
# Processing Record 19 of Set 6 | lexington
# Processing Record 20 of Set 6 | srandakan
# Processing Record 21 of Set 6 | mahuva
# Processing Record 22 of Set 6 | amahai
# Processing Record 23 of Set 6 | syracuse
# Processing Record 24 of Set 6 | uige
# Processing Record 25 of Set 6 | jieshi
# Processing Record 26 of Set 6 | providencia
# Processing Record 27 of Set 6 | balkanabat
# Processing Record 28 of Set 6 | saldanha
# Processing Record 29 of Set 6 | dzaoudzi
# Processing Record 30 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 6 | norman wells
# Processing Record 32 of Set 6 | hope
# Processing Record 33 of Set 6 | lavello
# Processing Record 34 of Set 6 | yei
# Processing Record 35 of Set 6 | bauchi
# Processing Record 36 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 6 | goderich
# Processing Record 38 of Set 6 | muyuka
# Processing Record 39 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 40 of Set 6 | bantry
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | port lincoln
# Processing Record 43 of Set 6 | tuatapere
# Processing Record 44 of Set 6 | northam
# Processing Record 45 of Set 6 | bambous virieux
# Processing Record 46 of Set 6 | faanui
# Processing Record 47 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 6 | vestmannaeyjar
# Processing Record 49 of Set 6 | arraial do cabo
# Processing Record 50 of Set 6 | biltine
# Processing Record 1 of Set 7 | swan hill
# Processing Record 2 of Set 7 | tolaga bay
# Processing Record 3 of Set 7 | jiuquan
# Processing Record 4 of Set 7 | bathsheba
# Processing Record 5 of Set 7 | sterling
# Processing Record 6 of Set 7 | kalmunai
# Processing Record 7 of Set 7 | sahuaripa
# Processing Record 8 of Set 7 | graham
# Processing Record 9 of Set 7 | vigia
# Processing Record 10 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 7 | longhua
# Processing Record 12 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 7 | brookhaven
# Processing Record 14 of Set 7 | ola
# Processing Record 15 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 7 | constitucion
# Processing Record 17 of Set 7 | ust-shonosha
# Processing Record 18 of Set 7 | srisailam
# Processing Record 19 of Set 7 | hovd
# Processing Record 20 of Set 7 | grand gaube
# Processing Record 21 of Set 7 | bayan
# Processing Record 22 of Set 7 | padang
# Processing Record 23 of Set 7 | katsuura
# Processing Record 24 of Set 7 | zalari
# Processing Record 25 of Set 7 | bichena
# Processing Record 26 of Set 7 | hofn
# Processing Record 27 of Set 7 | ntungamo
# Processing Record 28 of Set 7 | nanortalik
# Processing Record 29 of Set 7 | macas
# Processing Record 30 of Set 7 | halmstad
# Processing Record 31 of Set 7 | tondano
# Processing Record 32 of Set 7 | san juan de las huertas
# Processing Record 33 of Set 7 | adre
# Processing Record 34 of Set 7 | aguimes
# Processing Record 35 of Set 7 | sinnar
# Processing Record 36 of Set 7 | san vicente
# Processing Record 37 of Set 7 | kasempa
# Processing Record 38 of Set 7 | salekhard
# Processing Record 39 of Set 7 | berlevag
# Processing Record 40 of Set 7 | mafinga
# Processing Record 41 of Set 7 | shymkent
# Processing Record 42 of Set 7 | lata
# Processing Record 43 of Set 7 | hall
# Processing Record 44 of Set 7 | paamiut
# Processing Record 45 of Set 7 | karaton
# Processing Record 46 of Set 7 | kununurra
# Processing Record 47 of Set 7 | binabalian
# Processing Record 48 of Set 7 | omboue
# Processing Record 49 of Set 7 | russell
# Processing Record 50 of Set 7 | rudbar
# Processing Record 1 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 8 | kawalu
# Processing Record 3 of Set 8 | mendi
# Processing Record 4 of Set 8 | luena
# Processing Record 5 of Set 8 | ahipara
# Processing Record 6 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sitka
# Processing Record 8 of Set 8 | alofi
# Processing Record 9 of Set 8 | leningradskiy
# Processing Record 10 of Set 8 | mikhaylovsk
# Processing Record 11 of Set 8 | maryville
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | nova olinda do norte
# Processing Record 14 of Set 8 | inirida
# Processing Record 15 of Set 8 | half moon bay
# Processing Record 16 of Set 8 | talnakh
# Processing Record 17 of Set 8 | aswan
# Processing Record 18 of Set 8 | havoysund
# Processing Record 19 of Set 8 | tsumeb
# Processing Record 20 of Set 8 | sibut
# Processing Record 21 of Set 8 | sogne
# Processing Record 22 of Set 8 | santa cruz do rio pardo
# Processing Record 23 of Set 8 | nantucket
# Processing Record 24 of Set 8 | nelson bay
# Processing Record 25 of Set 8 | clarence town
# Processing Record 26 of Set 8 | mangaratiba
# Processing Record 27 of Set 8 | arlit
# Processing Record 28 of Set 8 | aitape
# Processing Record 29 of Set 8 | nalgonda
# Processing Record 30 of Set 8 | balingasay
# Processing Record 31 of Set 8 | andrelandia
# Processing Record 32 of Set 8 | yinchuan
# Processing Record 33 of Set 8 | acapulco
# Processing Record 34 of Set 8 | the valley
# Processing Record 35 of Set 8 | riaba
# City not found. Skipping...
# Processing Record 36 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 8 | celestun
# Processing Record 38 of Set 8 | west bay
# Processing Record 39 of Set 8 | sisimiut
# Processing Record 40 of Set 8 | mecca
# Processing Record 41 of Set 8 | fort nelson
# Processing Record 42 of Set 8 | dezhou
# Processing Record 43 of Set 8 | linqiong
# Processing Record 44 of Set 8 | chicama
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | tsogni
# Processing Record 47 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 8 | yeppoon
# Processing Record 49 of Set 8 | ambulu
# Processing Record 50 of Set 8 | aljezur
# Processing Record 1 of Set 9 | valenca
# Processing Record 2 of Set 9 | hokitika
# Processing Record 3 of Set 9 | tecoanapa
# Processing Record 4 of Set 9 | ranong
# Processing Record 5 of Set 9 | birjand
# Processing Record 6 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 9 | udarnyy
# Processing Record 9 of Set 9 | west odessa
# Processing Record 10 of Set 9 | castro
# Processing Record 11 of Set 9 | cidreira
# Processing Record 12 of Set 9 | puerto escondido
# Processing Record 13 of Set 9 | yuanli
# Processing Record 14 of Set 9 | oriximina
# Processing Record 15 of Set 9 | umm kaddadah
# Processing Record 16 of Set 9 | guipavas
# Processing Record 17 of Set 9 | taman
# Processing Record 18 of Set 9 | igarka
# Processing Record 19 of Set 9 | fernie
# Processing Record 20 of Set 9 | inhambane
# Processing Record 21 of Set 9 | henties bay
# Processing Record 22 of Set 9 | kavaratti
# Processing Record 23 of Set 9 | poronaysk
# Processing Record 24 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 9 | aksu
# Processing Record 26 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 9 | cairo
# Processing Record 28 of Set 9 | zapolyarnyy
# Processing Record 29 of Set 9 | chahuites
# Processing Record 30 of Set 9 | labuhan
# Processing Record 31 of Set 9 | gimbi
# Processing Record 32 of Set 9 | airai
# Processing Record 33 of Set 9 | iracoubo
# Processing Record 34 of Set 9 | vardo
# Processing Record 35 of Set 9 | baghdad
# Processing Record 36 of Set 9 | senneterre
# Processing Record 37 of Set 9 | domat
# Processing Record 38 of Set 9 | nova olimpia
# Processing Record 39 of Set 9 | road town
# Processing Record 40 of Set 9 | port blair
# Processing Record 41 of Set 9 | kyren
# Processing Record 42 of Set 9 | kindu
# Processing Record 43 of Set 9 | neuquen
# Processing Record 44 of Set 9 | ladario
# Processing Record 45 of Set 9 | naze
# Processing Record 46 of Set 9 | tura
# Processing Record 47 of Set 9 | iqaluit
# Processing Record 48 of Set 9 | samarai
# Processing Record 49 of Set 9 | homer
# Processing Record 50 of Set 9 | pechenga
# Processing Record 1 of Set 10 | ancud
# Processing Record 2 of Set 10 | umea
# Processing Record 3 of Set 10 | esso
# Processing Record 4 of Set 10 | tepusteca
# Processing Record 5 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 6 of Set 10 | mehamn
# Processing Record 7 of Set 10 | rio grande
# Processing Record 8 of Set 10 | pervomayskiy
# Processing Record 9 of Set 10 | svetlaya
# Processing Record 10 of Set 10 | san rafael
# Processing Record 11 of Set 10 | boa vista
# Processing Record 12 of Set 10 | gunjur
# Processing Record 13 of Set 10 | torbay
# Processing Record 14 of Set 10 | toamasina
# Processing Record 15 of Set 10 | carballo
# Processing Record 16 of Set 10 | coihaique
# Processing Record 17 of Set 10 | nokaneng
# Processing Record 18 of Set 10 | kuna
# Processing Record 19 of Set 10 | sao bento do sul
# Processing Record 20 of Set 10 | mwene-ditu
# Processing Record 21 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 10 | bone
# Processing Record 23 of Set 10 | taksimo
# Processing Record 24 of Set 10 | linjiang
# Processing Record 25 of Set 10 | usinsk
# Processing Record 26 of Set 10 | lichinga
# Processing Record 27 of Set 10 | port-gentil
# Processing Record 28 of Set 10 | mahibadhoo
# Processing Record 29 of Set 10 | mount pleasant
# Processing Record 30 of Set 10 | hami
# Processing Record 31 of Set 10 | nizhneudinsk
# Processing Record 32 of Set 10 | alice springs
# Processing Record 33 of Set 10 | ranghulu
# Processing Record 34 of Set 10 | nueva loja
# Processing Record 35 of Set 10 | ekpoma
# Processing Record 36 of Set 10 | srednekolymsk
# Processing Record 37 of Set 10 | kirkkonummi
# Processing Record 38 of Set 10 | havre-saint-pierre
# Processing Record 39 of Set 10 | waingapu
# Processing Record 40 of Set 10 | asyut
# Processing Record 41 of Set 10 | shaoxing
# Processing Record 42 of Set 10 | pelym
# Processing Record 43 of Set 10 | piacabucu
# Processing Record 44 of Set 10 | ambon
# Processing Record 45 of Set 10 | narsipatnam
# Processing Record 46 of Set 10 | erenhot
# Processing Record 47 of Set 10 | mariinsk
# Processing Record 48 of Set 10 | honggang
# Processing Record 49 of Set 10 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 50 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 1 of Set 11 | port macquarie
# Processing Record 2 of Set 11 | phan thiet
# Processing Record 3 of Set 11 | singarayakonda
# Processing Record 4 of Set 11 | pafos
# Processing Record 5 of Set 11 | north bend
# Processing Record 6 of Set 11 | cayambe
# Processing Record 7 of Set 11 | kudahuvadhoo
# Processing Record 8 of Set 11 | oxbow
# Processing Record 9 of Set 11 | rocha
# Processing Record 10 of Set 11 | dunedin
# Processing Record 11 of Set 11 | ahuimanu
# Processing Record 12 of Set 11 | berkak
# Processing Record 13 of Set 11 | tandil
# Processing Record 14 of Set 11 | greve strand
# Processing Record 15 of Set 11 | uri
# Processing Record 16 of Set 11 | husavik
# Processing Record 17 of Set 11 | cap malheureux
# Processing Record 18 of Set 11 | minas de barroteran
# Processing Record 19 of Set 11 | mul
# Processing Record 20 of Set 11 | bac lieu
# Processing Record 21 of Set 11 | chebsara
# Processing Record 22 of Set 11 | bandarbeyla
# Processing Record 23 of Set 11 | korla
# Processing Record 24 of Set 11 | bastrop
# Processing Record 25 of Set 11 | mana
# Processing Record 26 of Set 11 | payakumbuh
# Processing Record 27 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 11 | zyryanka
# Processing Record 30 of Set 11 | kazbegi
# City not found. Skipping...
# Processing Record 31 of Set 11 | caravelas
# Processing Record 32 of Set 11 | bereda
# Processing Record 33 of Set 11 | kahului
# Processing Record 34 of Set 11 | comodoro rivadavia
# Processing Record 35 of Set 11 | moramanga
# Processing Record 36 of Set 11 | tariba
# Processing Record 37 of Set 11 | vila
# Processing Record 38 of Set 11 | esmeraldas
# Processing Record 39 of Set 11 | pacific grove
# Processing Record 40 of Set 11 | vredendal
# Processing Record 41 of Set 11 | mujiayingzi
# Processing Record 42 of Set 11 | ambilobe
# Processing Record 43 of Set 11 | manutuke
# Processing Record 44 of Set 11 | burica
# City not found. Skipping...
# Processing Record 45 of Set 11 | pilar
# Processing Record 46 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 11 | matamoros
# Processing Record 48 of Set 11 | albanel
# Processing Record 49 of Set 11 | san ramon
# Processing Record 50 of Set 11 | jinchang
# Processing Record 1 of Set 12 | iskateley
# Processing Record 2 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 3 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 4 of Set 12 | neiafu
# Processing Record 5 of Set 12 | puta
# Processing Record 6 of Set 12 | college
# Processing Record 7 of Set 12 | riyadh
# Processing Record 8 of Set 12 | wynyard
# Processing Record 9 of Set 12 | lixourion
# Processing Record 10 of Set 12 | athmallik
# Processing Record 11 of Set 12 | miri
# Processing Record 12 of Set 12 | hobyo
# Processing Record 13 of Set 12 | azar shahr
# City not found. Skipping...
# Processing Record 14 of Set 12 | acapetahua
# Processing Record 15 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 12 | monte patria
# Processing Record 17 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 12 | toktogul
# Processing Record 19 of Set 12 | fecamp
# Processing Record 20 of Set 12 | leiyang
# Processing Record 21 of Set 12 | lipin bor
# Processing Record 22 of Set 12 | anaconda
# Processing Record 23 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 12 | leh
# Processing Record 25 of Set 12 | taltal
# Processing Record 26 of Set 12 | puqi
# Processing Record 27 of Set 12 | duartina
# Processing Record 28 of Set 12 | atar
# Processing Record 29 of Set 12 | tabora
# Processing Record 30 of Set 12 | sola
# Processing Record 31 of Set 12 | gazanjyk
# Processing Record 32 of Set 12 | la joya
# Processing Record 33 of Set 12 | guerrero negro
# Processing Record 34 of Set 12 | nha trang
# Processing Record 35 of Set 12 | yalta
# Processing Record 36 of Set 12 | tunxi
# City not found. Skipping...
# Processing Record 37 of Set 12 | toyooka
# Processing Record 38 of Set 12 | hualmay
# Processing Record 39 of Set 12 | annau
# Processing Record 40 of Set 12 | rodrigues alves
# Processing Record 41 of Set 12 | mesaria
# Processing Record 42 of Set 12 | ishigaki
# Processing Record 43 of Set 12 | stornoway
# Processing Record 44 of Set 12 | altona
# Processing Record 45 of Set 12 | billings
# Processing Record 46 of Set 12 | freeport
# Processing Record 47 of Set 12 | gat
# Processing Record 48 of Set 12 | pochinki
# Processing Record 49 of Set 12 | sao joao da barra
# Processing Record 50 of Set 12 | huilong
# Processing Record 1 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 13 | zabinka
# City not found. Skipping...
# Processing Record 3 of Set 13 | zhigansk
# Processing Record 4 of Set 13 | dryden
# Processing Record 5 of Set 13 | barcelos
# Processing Record 6 of Set 13 | ternate
# Processing Record 7 of Set 13 | mnogovershinnyy
# Processing Record 8 of Set 13 | zandvoort
# Processing Record 9 of Set 13 | nouakchott
# Processing Record 10 of Set 13 | linden
# Processing Record 11 of Set 13 | alakurtti
# Processing Record 12 of Set 13 | sampit
# Processing Record 13 of Set 13 | koltubanovskiy
# Processing Record 14 of Set 13 | sungaipenuh
# Processing Record 15 of Set 13 | burns lake
# Processing Record 16 of Set 13 | mokhotlong
# Processing Record 17 of Set 13 | preobrazheniye
# Processing Record 18 of Set 13 | mazagao
# Processing Record 19 of Set 13 | grand-santi
# Processing Record 20 of Set 13 | necochea
# Processing Record 21 of Set 13 | darnah
# Processing Record 22 of Set 13 | hay river
# Processing Record 23 of Set 13 | date
# Processing Record 24 of Set 13 | itarema
# Processing Record 25 of Set 13 | san angelo
# Processing Record 26 of Set 13 | glazov
# Processing Record 27 of Set 13 | simao
# Processing Record 28 of Set 13 | guider
# Processing Record 29 of Set 13 | kholtoson
# Processing Record 30 of Set 13 | vanavara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Luderitz -26.6481   15.1594     60.15        89           0
# 1        Albany  42.6001  -73.9662     34.41        81          24
# 2          Nome  64.5011 -165.4064     17.67        93         100
# 3   Kattivakkam  13.2167   80.3167     69.89        83         100
# 4         Kitui  -1.3670   38.0106     62.15        95         100
# 5  Punta Arenas -53.1500  -70.9167     46.51        76           0
# 6      Zalantun  48.0000  122.7167     16.54        64         100
# 7   Port Alfred -33.5906   26.8910     73.18        94          90
# 8      Khatanga  71.9667  102.5000     -9.26        99         100
# 9      Villazon -22.0866  -65.5942     55.36        56         100
#
#    Wind Speed Country                 Date
# 0        7.49      NA  2022-12-09 02:56:02
# 1        4.88      US  2022-12-09 02:54:07
# 2        5.75      US  2022-12-09 02:53:40
# 3       23.76      IN  2022-12-09 02:56:03
# 4        1.41      KE  2022-12-09 02:56:03
# 5       12.66      CL  2022-12-09 02:56:03
# 6       10.54      CN  2022-12-09 02:56:04
# 7        4.00      ZA  2022-12-09 02:56:04
# 8        2.86      RU  2022-12-09 02:56:05
# 9        6.11      BO  2022-12-09 02:56:05

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                   Tombouctou
# Country                        ML
# Date          2022-12-09 02:56:07
# Lat                          20.0
# Lng                          -3.0
# Max Temp                    72.25
# Humidity                       16
# Cloudiness                      0
# Wind Speed                   10.6
# Name: 13, dtype: object

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,240))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,305))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(5,60))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

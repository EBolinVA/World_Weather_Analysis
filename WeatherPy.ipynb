# %%
# Move this file to Homework folder into Weather_Analysis and git add, commit, push

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 657

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
#  Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | turayf
# Processing Record 2 of Set 1 | vestmanna
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | mount isa
# Processing Record 9 of Set 1 | calabozo
# Processing Record 10 of Set 1 | yichun
# Processing Record 11 of Set 1 | edewecht
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | japura
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | bunia
# Processing Record 20 of Set 1 | kaeo
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | camocim
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | belaya gora
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | singkawang
# Processing Record 30 of Set 1 | zwedru
# Processing Record 31 of Set 1 | souillac
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | sobolevo
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | nishihara
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 1 | bhag
# Processing Record 41 of Set 1 | opuwo
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | preobrazheniye
# Processing Record 45 of Set 1 | aberdeen
# Processing Record 46 of Set 1 | shingu
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | lata
# Processing Record 3 of Set 2 | labuhan
# Processing Record 4 of Set 2 | tautira
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | te anau
# Processing Record 10 of Set 2 | los llanos de aridane
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | hami
# Processing Record 14 of Set 2 | leningradskiy
# Processing Record 15 of Set 2 | ambon
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 2 | alamosa
# Processing Record 19 of Set 2 | laguna
# Processing Record 20 of Set 2 | tura
# Processing Record 21 of Set 2 | sterling
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | igrim
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | mataura
# Processing Record 26 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 2 | sayyan
# Processing Record 28 of Set 2 | biak
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | okitipupa
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | aksarka
# Processing Record 34 of Set 2 | sukumo
# Processing Record 35 of Set 2 | hovd
# Processing Record 36 of Set 2 | anadyr
# Processing Record 37 of Set 2 | wagar
# Processing Record 38 of Set 2 | warrensburg
# Processing Record 39 of Set 2 | ulladulla
# Processing Record 40 of Set 2 | cockburn town
# Processing Record 41 of Set 2 | oriximina
# Processing Record 42 of Set 2 | avera
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | san cristobal
# Processing Record 45 of Set 2 | gazimagusa
# City not found. Skipping...
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | alofi
# Processing Record 48 of Set 2 | marfino
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | alta floresta
# Processing Record 2 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | lakes entrance
# Processing Record 5 of Set 3 | galle
# Processing Record 6 of Set 3 | linden
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | markova
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | popondetta
# Processing Record 13 of Set 3 | antalaha
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | tirano
# Processing Record 16 of Set 3 | asilah
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | canberra
# Processing Record 19 of Set 3 | sampit
# Processing Record 20 of Set 3 | lorengau
# Processing Record 21 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 3 | liverpool
# Processing Record 23 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 3 | fortuna
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | tres arroyos
# Processing Record 27 of Set 3 | plastun
# Processing Record 28 of Set 3 | sabang
# Processing Record 29 of Set 3 | ishurdi
# Processing Record 30 of Set 3 | ukiah
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | grants pass
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | ostrovnoy
# Processing Record 35 of Set 3 | tomatlan
# Processing Record 36 of Set 3 | isangel
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | nouadhibou
# Processing Record 39 of Set 3 | sinnamary
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | esso
# Processing Record 42 of Set 3 | mingaora
# Processing Record 43 of Set 3 | kurchum
# Processing Record 44 of Set 3 | broken hill
# Processing Record 45 of Set 3 | mackay
# Processing Record 46 of Set 3 | gulshat
# City not found. Skipping...
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | maragogi
# Processing Record 49 of Set 3 | mariental
# Processing Record 50 of Set 3 | sumbe
# Processing Record 1 of Set 4 | lavrentiya
# Processing Record 2 of Set 4 | basco
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | belmonte
# Processing Record 5 of Set 4 | cidreira
# Processing Record 6 of Set 4 | sri aman
# Processing Record 7 of Set 4 | adrar
# Processing Record 8 of Set 4 | brest
# Processing Record 9 of Set 4 | silver city
# Processing Record 10 of Set 4 | vanimo
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | nijar
# Processing Record 14 of Set 4 | aklavik
# Processing Record 15 of Set 4 | belyy yar
# Processing Record 16 of Set 4 | lazaro cardenas
# Processing Record 17 of Set 4 | mahaicony
# City not found. Skipping...
# Processing Record 18 of Set 4 | hermanus
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 21 of Set 4 | ust-kuyga
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | moyo
# Processing Record 24 of Set 4 | vyartsilya
# Processing Record 25 of Set 4 | saint-georges
# Processing Record 26 of Set 4 | skoghall
# Processing Record 27 of Set 4 | saint-joseph
# Processing Record 28 of Set 4 | teseney
# Processing Record 29 of Set 4 | egvekinot
# Processing Record 30 of Set 4 | esperance
# Processing Record 31 of Set 4 | bara
# Processing Record 32 of Set 4 | swan river
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | andenes
# Processing Record 35 of Set 4 | nizhniy tsasuchey
# Processing Record 36 of Set 4 | kostomuksha
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | coquimbo
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | santa helena
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | margate
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | chapulhuacan
# Processing Record 45 of Set 4 | port macquarie
# Processing Record 46 of Set 4 | springdale
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | suntar
# Processing Record 49 of Set 4 | dzerzhinsk
# Processing Record 50 of Set 4 | miles city
# Processing Record 1 of Set 5 | richards bay
# Processing Record 2 of Set 5 | upernavik
# Processing Record 3 of Set 5 | chapada dos guimaraes
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | chuy
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | easley
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | oskaloosa
# Processing Record 10 of Set 5 | cervo
# Processing Record 11 of Set 5 | treinta y tres
# Processing Record 12 of Set 5 | butka
# Processing Record 13 of Set 5 | north bend
# Processing Record 14 of Set 5 | nakanojo
# Processing Record 15 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 5 | kananga
# Processing Record 17 of Set 5 | pangai
# Processing Record 18 of Set 5 | inirida
# Processing Record 19 of Set 5 | betsiamites
# Processing Record 20 of Set 5 | lusambo
# Processing Record 21 of Set 5 | dali
# Processing Record 22 of Set 5 | khash
# Processing Record 23 of Set 5 | carutapera
# Processing Record 24 of Set 5 | mackenzie
# Processing Record 25 of Set 5 | xuanhua
# Processing Record 26 of Set 5 | sagua de tanamo
# Processing Record 27 of Set 5 | cortez
# Processing Record 28 of Set 5 | bafoulabe
# Processing Record 29 of Set 5 | tigil
# Processing Record 30 of Set 5 | yeppoon
# Processing Record 31 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 5 | haines junction
# Processing Record 33 of Set 5 | beringovskiy
# Processing Record 34 of Set 5 | gimli
# Processing Record 35 of Set 5 | jizan
# Processing Record 36 of Set 5 | coracao de jesus
# Processing Record 37 of Set 5 | la ciotat
# Processing Record 38 of Set 5 | saint-leu
# Processing Record 39 of Set 5 | pundaguitan
# Processing Record 40 of Set 5 | alexandria
# Processing Record 41 of Set 5 | dengzhou
# Processing Record 42 of Set 5 | usinsk
# Processing Record 43 of Set 5 | zaterechnyy
# Processing Record 44 of Set 5 | oxelosund
# Processing Record 45 of Set 5 | orgun
# City not found. Skipping...
# Processing Record 46 of Set 5 | beisfjord
# Processing Record 47 of Set 5 | taltal
# Processing Record 48 of Set 5 | tete
# Processing Record 49 of Set 5 | clearwater
# Processing Record 50 of Set 5 | san carlos de bariloche
# Processing Record 1 of Set 6 | havoysund
# Processing Record 2 of Set 6 | pedernales
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | ayan
# Processing Record 5 of Set 6 | wanaka
# Processing Record 6 of Set 6 | nioro
# Processing Record 7 of Set 6 | waddan
# Processing Record 8 of Set 6 | mehamn
# Processing Record 9 of Set 6 | seguela
# Processing Record 10 of Set 6 | koungheul
# Processing Record 11 of Set 6 | dingle
# Processing Record 12 of Set 6 | tiznit
# Processing Record 13 of Set 6 | hinton
# Processing Record 14 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | ancud
# Processing Record 18 of Set 6 | tongchuan
# Processing Record 19 of Set 6 | plettenberg bay
# Processing Record 20 of Set 6 | tolmin
# Processing Record 21 of Set 6 | saint-francois
# Processing Record 22 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 6 | zhezkazgan
# Processing Record 24 of Set 6 | fereydun kenar
# Processing Record 25 of Set 6 | bartica
# Processing Record 26 of Set 6 | thaba nchu
# Processing Record 27 of Set 6 | pahrump
# Processing Record 28 of Set 6 | bodh gaya
# Processing Record 29 of Set 6 | georgetown
# Processing Record 30 of Set 6 | nadym
# Processing Record 31 of Set 6 | barcelos
# Processing Record 32 of Set 6 | maceio
# Processing Record 33 of Set 6 | lixourion
# Processing Record 34 of Set 6 | balkhash
# Processing Record 35 of Set 6 | bar harbor
# Processing Record 36 of Set 6 | saint cloud
# Processing Record 37 of Set 6 | chaoyang
# Processing Record 38 of Set 6 | bambous virieux
# Processing Record 39 of Set 6 | mutoko
# Processing Record 40 of Set 6 | portland
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | kununurra
# Processing Record 43 of Set 6 | norman wells
# Processing Record 44 of Set 6 | kenora
# Processing Record 45 of Set 6 | senador jose porfirio
# Processing Record 46 of Set 6 | cam ranh
# Processing Record 47 of Set 6 | racine
# Processing Record 48 of Set 6 | chenghai
# Processing Record 49 of Set 6 | aksu
# Processing Record 50 of Set 6 | kodiak
# Processing Record 1 of Set 7 | toamasina
# Processing Record 2 of Set 7 | katsuura
# Processing Record 3 of Set 7 | pachora
# Processing Record 4 of Set 7 | dudinka
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | mati
# Processing Record 7 of Set 7 | puro
# Processing Record 8 of Set 7 | faanui
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | poso
# Processing Record 11 of Set 7 | aykhal
# Processing Record 12 of Set 7 | cabo san lucas
# Processing Record 13 of Set 7 | miandrivazo
# Processing Record 14 of Set 7 | hammerfest
# Processing Record 15 of Set 7 | rivne
# Processing Record 16 of Set 7 | koupela
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | port lincoln
# Processing Record 19 of Set 7 | norton
# Processing Record 20 of Set 7 | bulawayo
# Processing Record 21 of Set 7 | puerto escondido
# Processing Record 22 of Set 7 | ahipara
# Processing Record 23 of Set 7 | poya
# Processing Record 24 of Set 7 | ustye
# Processing Record 25 of Set 7 | talcahuano
# Processing Record 26 of Set 7 | bafra
# Processing Record 27 of Set 7 | douentza
# Processing Record 28 of Set 7 | sosnovo-ozerskoye
# Processing Record 29 of Set 7 | cayenne
# Processing Record 30 of Set 7 | saint george
# Processing Record 31 of Set 7 | bahir dar
# Processing Record 32 of Set 7 | san ignacio
# Processing Record 33 of Set 7 | hualmay
# Processing Record 34 of Set 7 | husavik
# Processing Record 35 of Set 7 | hamilton
# Processing Record 36 of Set 7 | pechora
# Processing Record 37 of Set 7 | sisimiut
# Processing Record 38 of Set 7 | tanah merah
# Processing Record 39 of Set 7 | reforma
# Processing Record 40 of Set 7 | palmas de monte alto
# Processing Record 41 of Set 7 | arkhara
# Processing Record 42 of Set 7 | san vicente
# Processing Record 43 of Set 7 | misratah
# Processing Record 44 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 7 | baracoa
# Processing Record 46 of Set 7 | kruisfontein
# Processing Record 47 of Set 7 | loa janan
# Processing Record 48 of Set 7 | mabaruma
# Processing Record 49 of Set 7 | ambilobe
# Processing Record 50 of Set 7 | palu
# Processing Record 1 of Set 8 | puerto del rosario
# Processing Record 2 of Set 8 | zanatepec
# City not found. Skipping...
# Processing Record 3 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 8 | cabo rojo
# Processing Record 5 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 8 | sandovo
# Processing Record 7 of Set 8 | carballo
# Processing Record 8 of Set 8 | lompoc
# Processing Record 9 of Set 8 | fecamp
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | clyde river
# Processing Record 12 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 13 of Set 8 | alihe
# Processing Record 14 of Set 8 | nieuw amsterdam
# Processing Record 15 of Set 8 | ulaangom
# Processing Record 16 of Set 8 | valdivia
# Processing Record 17 of Set 8 | santa cecilia
# Processing Record 18 of Set 8 | jodhpur
# Processing Record 19 of Set 8 | sola
# Processing Record 20 of Set 8 | nome
# Processing Record 21 of Set 8 | koboko
# Processing Record 22 of Set 8 | kholmsk
# Processing Record 23 of Set 8 | grand gaube
# Processing Record 24 of Set 8 | bosobolo
# Processing Record 25 of Set 8 | urfa
# City not found. Skipping...
# Processing Record 26 of Set 8 | tianpeng
# Processing Record 27 of Set 8 | tinaquillo
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | vardo
# Processing Record 30 of Set 8 | port moresby
# Processing Record 31 of Set 8 | mezen
# Processing Record 32 of Set 8 | novoshcherbinovskaya
# Processing Record 33 of Set 8 | atambua
# Processing Record 34 of Set 8 | viedma
# Processing Record 35 of Set 8 | ngaoundere
# Processing Record 36 of Set 8 | neuquen
# Processing Record 37 of Set 8 | clifton
# Processing Record 38 of Set 8 | rotterdam
# Processing Record 39 of Set 8 | iqaluit
# Processing Record 40 of Set 8 | badamdar
# Processing Record 41 of Set 8 | llano de piedra
# Processing Record 42 of Set 8 | rio gallegos
# Processing Record 43 of Set 8 | namibe
# Processing Record 44 of Set 8 | saldanha
# Processing Record 45 of Set 8 | massakory
# Processing Record 46 of Set 8 | moose jaw
# Processing Record 47 of Set 8 | yaan
# Processing Record 48 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 8 | lagoa
# Processing Record 50 of Set 8 | vila franca do campo
# Processing Record 1 of Set 9 | ambalavao
# Processing Record 2 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 9 | seminole
# Processing Record 4 of Set 9 | talnakh
# Processing Record 5 of Set 9 | sao joao da barra
# Processing Record 6 of Set 9 | vila velha
# Processing Record 7 of Set 9 | dubrovka
# Processing Record 8 of Set 9 | muros
# Processing Record 9 of Set 9 | san quintin
# Processing Record 10 of Set 9 | yarada
# Processing Record 11 of Set 9 | kyaikto
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | capelinha
# Processing Record 14 of Set 9 | chimbote
# Processing Record 15 of Set 9 | robertson
# Processing Record 16 of Set 9 | charlestown
# Processing Record 17 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 9 | edea
# Processing Record 19 of Set 9 | shihezi
# Processing Record 20 of Set 9 | mahabad
# Processing Record 21 of Set 9 | baruun-urt
# Processing Record 22 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 23 of Set 9 | atasu
# Processing Record 24 of Set 9 | puerto penasco
# Processing Record 25 of Set 9 | farafangana
# Processing Record 26 of Set 9 | mount gambier
# Processing Record 27 of Set 9 | san policarpo
# Processing Record 28 of Set 9 | longkou
# Processing Record 29 of Set 9 | nyimba
# Processing Record 30 of Set 9 | tuatapere
# Processing Record 31 of Set 9 | saint-paul
# Processing Record 32 of Set 9 | beira
# Processing Record 33 of Set 9 | atar
# Processing Record 34 of Set 9 | vila do maio
# Processing Record 35 of Set 9 | noumea
# Processing Record 36 of Set 9 | waingapu
# Processing Record 37 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 38 of Set 9 | cankuzo
# Processing Record 39 of Set 9 | sayville
# Processing Record 40 of Set 9 | aleksandrov gay
# Processing Record 41 of Set 9 | jian
# Processing Record 42 of Set 9 | yenagoa
# Processing Record 43 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 9 | dunedin
# Processing Record 45 of Set 9 | tessalit
# Processing Record 46 of Set 9 | nynashamn
# Processing Record 47 of Set 9 | naze
# Processing Record 48 of Set 9 | beihai
# Processing Record 49 of Set 9 | batemans bay
# Processing Record 50 of Set 9 | antofagasta
# Processing Record 1 of Set 10 | hambantota
# Processing Record 2 of Set 10 | la ronge
# Processing Record 3 of Set 10 | letpadan
# Processing Record 4 of Set 10 | rocha
# Processing Record 5 of Set 10 | east renton highlands
# Processing Record 6 of Set 10 | jalu
# Processing Record 7 of Set 10 | kaniama
# Processing Record 8 of Set 10 | camacha
# Processing Record 9 of Set 10 | vuktyl
# Processing Record 10 of Set 10 | syracuse
# Processing Record 11 of Set 10 | gat
# Processing Record 12 of Set 10 | mbandaka
# Processing Record 13 of Set 10 | caravelas
# Processing Record 14 of Set 10 | canete
# Processing Record 15 of Set 10 | high level
# Processing Record 16 of Set 10 | zhangjiakou
# Processing Record 17 of Set 10 | gisborne
# Processing Record 18 of Set 10 | mansa
# Processing Record 19 of Set 10 | lofthus
# Processing Record 20 of Set 10 | hofn
# Processing Record 21 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 10 | sainte-rose
# Processing Record 23 of Set 10 | trincomalee
# Processing Record 24 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 10 | rancho veloz
# Processing Record 26 of Set 10 | bethel
# Processing Record 27 of Set 10 | bubaque
# Processing Record 28 of Set 10 | logansport
# Processing Record 29 of Set 10 | port blair
# Processing Record 30 of Set 10 | udachnyy
# Processing Record 31 of Set 10 | santa lucia
# Processing Record 32 of Set 10 | ios
# Processing Record 33 of Set 10 | shimoda
# Processing Record 34 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 35 of Set 10 | entrerrios
# Processing Record 36 of Set 10 | neiafu
# Processing Record 37 of Set 10 | odweyne
# Processing Record 38 of Set 10 | leeton
# Processing Record 39 of Set 10 | sorland
# Processing Record 40 of Set 10 | kambove
# Processing Record 41 of Set 10 | yurkivka
# Processing Record 42 of Set 10 | maniitsoq
# Processing Record 43 of Set 10 | rio cauto
# Processing Record 44 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 10 | vostok
# Processing Record 46 of Set 10 | macau
# Processing Record 47 of Set 10 | katha
# City not found. Skipping...
# Processing Record 48 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 10 | dhidhdhoo
# Processing Record 50 of Set 10 | nerchinskiy zavod
# Processing Record 1 of Set 11 | makinsk
# Processing Record 2 of Set 11 | puerto narino
# Processing Record 3 of Set 11 | parrita
# Processing Record 4 of Set 11 | ocos
# Processing Record 5 of Set 11 | arona
# Processing Record 6 of Set 11 | santa cruz cabralia
# Processing Record 7 of Set 11 | presidencia roque saenz pena
# Processing Record 8 of Set 11 | peniche
# Processing Record 9 of Set 11 | yermakovskoye
# Processing Record 10 of Set 11 | bintulu
# Processing Record 11 of Set 11 | samarai
# Processing Record 12 of Set 11 | hatillo
# Processing Record 13 of Set 11 | salalah
# Processing Record 14 of Set 11 | nemuro
# Processing Record 15 of Set 11 | ngunguru
# Processing Record 16 of Set 11 | staryy krym
# Processing Record 17 of Set 11 | gryazovets
# Processing Record 18 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 11 | constitucion
# Processing Record 20 of Set 11 | qeshm
# Processing Record 21 of Set 11 | whitehorse
# Processing Record 22 of Set 11 | monywa
# Processing Record 23 of Set 11 | nehe
# Processing Record 24 of Set 11 | zhaotong
# Processing Record 25 of Set 11 | filingue
# Processing Record 26 of Set 11 | mandali
# Processing Record 27 of Set 11 | balaipungut
# Processing Record 28 of Set 11 | pipri
# Processing Record 29 of Set 11 | kamenka
# Processing Record 30 of Set 11 | duku
# Processing Record 31 of Set 11 | masindi
# Processing Record 32 of Set 11 | teknaf
# Processing Record 33 of Set 11 | macklin
# Processing Record 34 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 11 | oktyabrskiy
# Processing Record 36 of Set 11 | ginda
# Processing Record 37 of Set 11 | jinchang
# Processing Record 38 of Set 11 | gizo
# Processing Record 39 of Set 11 | pontarlier
# Processing Record 40 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 11 | kalmunai
# Processing Record 42 of Set 11 | harrismith
# Processing Record 43 of Set 11 | lasa
# Processing Record 44 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 45 of Set 11 | katobu
# Processing Record 46 of Set 11 | fredericton
# Processing Record 47 of Set 11 | makarov
# Processing Record 48 of Set 11 | nelspruit
# Processing Record 49 of Set 11 | nanjing
# Processing Record 50 of Set 11 | dutlwe
# Processing Record 1 of Set 12 | bela
# Processing Record 2 of Set 12 | leiyang
# Processing Record 3 of Set 12 | progreso
# Processing Record 4 of Set 12 | stutterheim
# Processing Record 5 of Set 12 | tazovskiy
# Processing Record 6 of Set 12 | masuguru
# Processing Record 7 of Set 12 | asau
# Processing Record 8 of Set 12 | satinka
# Processing Record 9 of Set 12 | tazmalt
# Processing Record 10 of Set 12 | darhan
# Processing Record 11 of Set 12 | asyut
# Processing Record 12 of Set 12 | cairns
# Processing Record 13 of Set 12 | corsicana
# Processing Record 14 of Set 12 | karratha
# Processing Record 15 of Set 12 | djenne
# Processing Record 16 of Set 12 | coahuayana
# Processing Record 17 of Set 12 | culebra
# Processing Record 18 of Set 12 | ponta delgada
# Processing Record 19 of Set 12 | port arthur
# Processing Record 20 of Set 12 | adre
# Processing Record 21 of Set 12 | ploemeur
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | tampere
# Processing Record 24 of Set 12 | kibre mengist
# Processing Record 25 of Set 12 | yatou
# Processing Record 26 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 27 of Set 12 | khor
# Processing Record 28 of Set 12 | hirara
# Processing Record 29 of Set 12 | alampur
# Processing Record 30 of Set 12 | garcia
# Processing Record 31 of Set 12 | jumla
# Processing Record 32 of Set 12 | chipinge
# Processing Record 33 of Set 12 | nampula
# Processing Record 34 of Set 12 | blackwater
# Processing Record 35 of Set 12 | humaita
# Processing Record 36 of Set 12 | caconda
# Processing Record 37 of Set 12 | bani
# Processing Record 38 of Set 12 | kieta
# Processing Record 39 of Set 12 | jatoi
# City not found. Skipping...
# Processing Record 40 of Set 12 | manta
# Processing Record 41 of Set 12 | luwuk
# Processing Record 42 of Set 12 | harper
# Processing Record 43 of Set 12 | champerico
# Processing Record 44 of Set 12 | cozumel
# Processing Record 45 of Set 12 | kindu
# Processing Record 46 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 12 | soverato
# Processing Record 48 of Set 12 | touros
# Processing Record 49 of Set 12 | santa fe
# Processing Record 50 of Set 12 | hihya
# Processing Record 1 of Set 13 | coro
# Processing Record 2 of Set 13 | yar-sale
# Processing Record 3 of Set 13 | wundanyi
# Processing Record 4 of Set 13 | tarakan
# Processing Record 5 of Set 13 | alice springs
# Processing Record 6 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 13 | paamiut
# Processing Record 8 of Set 13 | omutinskoye
# City not found. Skipping...
# Processing Record 9 of Set 13 | xunchang
# Processing Record 10 of Set 13 | colares
# Processing Record 11 of Set 13 | livingstone
# Processing Record 12 of Set 13 | ust-omchug
# Processing Record 13 of Set 13 | haicheng
# Processing Record 14 of Set 13 | saqqez
# Processing Record 15 of Set 13 | balykshi
# Processing Record 16 of Set 13 | lima
# Processing Record 17 of Set 13 | merauke
# Processing Record 18 of Set 13 | manzhouli
# Processing Record 19 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 13 | kudahuvadhoo
# Processing Record 21 of Set 13 | lensk
# Processing Record 22 of Set 13 | krasnoselkup
# Processing Record 23 of Set 13 | pouebo
# Processing Record 24 of Set 13 | xinyang
# Processing Record 25 of Set 13 | ugoofaaru
# Processing Record 26 of Set 13 | kadom
# Processing Record 27 of Set 13 | ifanadiana
# Processing Record 28 of Set 13 | san andres
# Processing Record 29 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 13 | la victoria
# Processing Record 31 of Set 13 | lugovoy
# Processing Record 32 of Set 13 | palafrugell
# Processing Record 33 of Set 13 | ossora
# Processing Record 34 of Set 13 | pingzhuang
# Processing Record 35 of Set 13 | manama
# Processing Record 36 of Set 13 | boatlaname
# City not found. Skipping...
# Processing Record 37 of Set 13 | ereymentau
# Processing Record 38 of Set 13 | marzuq
# Processing Record 39 of Set 13 | marawi
# Processing Record 40 of Set 13 | seoni malwa
# Processing Record 41 of Set 13 | anaconda
# Processing Record 42 of Set 13 | rognan
# Processing Record 43 of Set 13 | saint anthony
# Processing Record 44 of Set 13 | skibbereen
# Processing Record 45 of Set 13 | beidao
# Processing Record 46 of Set 13 | poum
# Processing Record 47 of Set 13 | port hedland
# Processing Record 48 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 49 of Set 13 | nabire
# Processing Record 50 of Set 13 | mme
# City not found. Skipping...
# Processing Record 1 of Set 14 | berlevag
# Processing Record 2 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 14 | hit
# Processing Record 4 of Set 14 | omboue
# Processing Record 5 of Set 14 | vao
# Processing Record 6 of Set 14 | palmer
# Processing Record 7 of Set 14 | hobyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Turayf  31.6725   38.6637    285.20        67          29        1.48
# 1  Vestmanna  62.1564   -7.1664    274.66        60         100        7.20
# 2  Busselton -33.6500  115.3333    287.62        67           8        7.14
# 3    Qaanaaq  77.4840  -69.3632    272.71        69         100        4.28
# 4      Pevek  69.7008  170.3133    259.71        95         100        3.10
# 5     Dikson  73.5069   80.5464    258.54        98          86        3.78
# 6  Mount Isa -20.7333  139.5000    306.02        29           1        5.66
# 7   Calabozo   8.9242  -67.4293    299.49        48           9        0.74
# 8     Yichun  47.7000  128.9000    257.31        97          98        1.13
# 9   Edewecht  53.1333    7.9833    277.67        98          72        4.33
#
#   Country                 Date
# 0      SA  2022-12-06 23:05:58
# 1      FO  2022-12-06 23:05:58
# 2      AU  2022-12-06 23:05:59
# 3      GL  2022-12-06 23:05:59
# 4      RU  2022-12-06 23:05:59
# 5      RU  2022-12-06 23:06:00
# 6      AU  2022-12-06 23:01:30
# 7      VE  2022-12-06 23:06:01
# 8      CN  2022-12-06 23:06:01
# 9      DE  2022-12-06 23:06:01

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

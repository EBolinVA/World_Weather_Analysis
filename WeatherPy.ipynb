# %%
# Move this file to Homework folder into Weather_Analysis and git add, commit, push

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
#  Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?&appid=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | kalmar
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | san ignacio
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | mildura
# Processing Record 9 of Set 1 | half moon bay
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | liverpool
# Processing Record 13 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 1 | zhigansk
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | banda aceh
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | kushmurun
# Processing Record 19 of Set 1 | qaqortoq
# Processing Record 20 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | toulepleu
# City not found. Skipping...
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | mareeba
# Processing Record 26 of Set 1 | katsuura
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | innisfail
# Processing Record 30 of Set 1 | maragogi
# Processing Record 31 of Set 1 | la asuncion
# Processing Record 32 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | virginia beach
# Processing Record 40 of Set 1 | marzuq
# Processing Record 41 of Set 1 | rocha
# Processing Record 42 of Set 1 | lasa
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | honiara
# Processing Record 47 of Set 1 | buraydah
# Processing Record 48 of Set 1 | russas
# Processing Record 49 of Set 1 | mount isa
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | teya
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | atar
# Processing Record 6 of Set 2 | reus
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | northam
# Processing Record 9 of Set 2 | nhulunbuy
# Processing Record 10 of Set 2 | waterloo
# Processing Record 11 of Set 2 | neuquen
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | taunggyi
# Processing Record 14 of Set 2 | ballina
# Processing Record 15 of Set 2 | abnub
# Processing Record 16 of Set 2 | ilulissat
# Processing Record 17 of Set 2 | nedjo
# Processing Record 18 of Set 2 | togul
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | kamiiso
# Processing Record 21 of Set 2 | abilene
# Processing Record 22 of Set 2 | korla
# Processing Record 23 of Set 2 | prince rupert
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | bara
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | clyde river
# Processing Record 31 of Set 2 | upernavik
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | dasoguz
# Processing Record 34 of Set 2 | sava
# Processing Record 35 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 2 | jesenik
# Processing Record 37 of Set 2 | puerto asis
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | shimoda
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | nguruka
# Processing Record 42 of Set 2 | vila velha
# Processing Record 43 of Set 2 | road town
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | whitehorse
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | port said
# Processing Record 2 of Set 3 | ancud
# Processing Record 3 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | rocky mountain house
# Processing Record 6 of Set 3 | salalah
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | marsa matruh
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | ahipara
# Processing Record 11 of Set 3 | cockburn town
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 3 | jeremie
# Processing Record 15 of Set 3 | pombas
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | bambous virieux
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | san quintin
# Processing Record 24 of Set 3 | yairipok
# Processing Record 25 of Set 3 | andrelandia
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | bilibino
# Processing Record 28 of Set 3 | haldibari
# Processing Record 29 of Set 3 | fort frances
# Processing Record 30 of Set 3 | comodoro rivadavia
# Processing Record 31 of Set 3 | tebingtinggi
# Processing Record 32 of Set 3 | ulladulla
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | najran
# Processing Record 36 of Set 3 | dibulla
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | hasaki
# Processing Record 39 of Set 3 | coahuayana
# Processing Record 40 of Set 3 | kitimat
# Processing Record 41 of Set 3 | jequitinhonha
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | beachwood
# Processing Record 44 of Set 3 | alofi
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | waingapu
# Processing Record 47 of Set 3 | nizhniy ingash
# Processing Record 48 of Set 3 | praia
# Processing Record 49 of Set 3 | moiyabana
# City not found. Skipping...
# Processing Record 50 of Set 3 | asuncion
# Processing Record 1 of Set 4 | axim
# Processing Record 2 of Set 4 | takoradi
# Processing Record 3 of Set 4 | bartica
# Processing Record 4 of Set 4 | bardiyah
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | sur
# Processing Record 7 of Set 4 | ust-nera
# Processing Record 8 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 4 | labuhan
# Processing Record 10 of Set 4 | te horo
# Processing Record 11 of Set 4 | mitu
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | port alfred
# Processing Record 15 of Set 4 | avera
# Processing Record 16 of Set 4 | khatanga
# Processing Record 17 of Set 4 | tambura
# Processing Record 18 of Set 4 | ous
# Processing Record 19 of Set 4 | kearney
# Processing Record 20 of Set 4 | sunrise manor
# Processing Record 21 of Set 4 | galesong
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | aswan
# Processing Record 24 of Set 4 | flinders
# Processing Record 25 of Set 4 | college
# Processing Record 26 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 4 | atasu
# Processing Record 28 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 4 | iskateley
# Processing Record 32 of Set 4 | kavaratti
# Processing Record 33 of Set 4 | mandal
# Processing Record 34 of Set 4 | banepa
# Processing Record 35 of Set 4 | parati
# Processing Record 36 of Set 4 | issaquah
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | singaraja
# Processing Record 39 of Set 4 | oksovskiy
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 43 of Set 4 | bereda
# Processing Record 44 of Set 4 | goderich
# Processing Record 45 of Set 4 | oranjestad
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | sechura
# Processing Record 48 of Set 4 | imbituba
# Processing Record 49 of Set 4 | merauke
# Processing Record 50 of Set 4 | san patricio
# Processing Record 1 of Set 5 | manzil tamim
# City not found. Skipping...
# Processing Record 2 of Set 5 | vao
# Processing Record 3 of Set 5 | anadyr
# Processing Record 4 of Set 5 | santa cruz
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | qaanaaq
# Processing Record 7 of Set 5 | abatskoye
# Processing Record 8 of Set 5 | ponta do sol
# Processing Record 9 of Set 5 | shingu
# Processing Record 10 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 5 | caravelas
# Processing Record 12 of Set 5 | smithers
# Processing Record 13 of Set 5 | itanagar
# Processing Record 14 of Set 5 | komsomolskiy
# Processing Record 15 of Set 5 | namatanai
# Processing Record 16 of Set 5 | omsukchan
# Processing Record 17 of Set 5 | corbasca
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | la ronge
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | coihaique
# Processing Record 22 of Set 5 | saint-pierre
# Processing Record 23 of Set 5 | soma
# Processing Record 24 of Set 5 | te anau
# Processing Record 25 of Set 5 | pontes e lacerda
# Processing Record 26 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 27 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 5 | amatan
# Processing Record 29 of Set 5 | jamestown
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | senanga
# Processing Record 32 of Set 5 | voi
# Processing Record 33 of Set 5 | kokopo
# Processing Record 34 of Set 5 | inhambane
# Processing Record 35 of Set 5 | opuwo
# Processing Record 36 of Set 5 | minden
# Processing Record 37 of Set 5 | bubaque
# Processing Record 38 of Set 5 | tyshkivka
# Processing Record 39 of Set 5 | tongsa
# City not found. Skipping...
# Processing Record 40 of Set 5 | benguela
# Processing Record 41 of Set 5 | falmouth
# Processing Record 42 of Set 5 | powell
# Processing Record 43 of Set 5 | hualmay
# Processing Record 44 of Set 5 | sioux lookout
# Processing Record 45 of Set 5 | laguna
# Processing Record 46 of Set 5 | dingle
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | sola
# Processing Record 49 of Set 5 | fallon
# Processing Record 50 of Set 5 | skibbereen
# Processing Record 1 of Set 6 | grindavik
# Processing Record 2 of Set 6 | adre
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | kiruna
# Processing Record 5 of Set 6 | tomatlan
# Processing Record 6 of Set 6 | santacruz
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | thunder bay
# Processing Record 9 of Set 6 | aquin
# Processing Record 10 of Set 6 | talaya
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | nabire
# Processing Record 13 of Set 6 | mahanoro
# Processing Record 14 of Set 6 | yanji
# Processing Record 15 of Set 6 | springbok
# Processing Record 16 of Set 6 | souillac
# Processing Record 17 of Set 6 | fortuna
# Processing Record 18 of Set 6 | hetauda
# Processing Record 19 of Set 6 | brodokalmak
# Processing Record 20 of Set 6 | mayo
# Processing Record 21 of Set 6 | pisco
# Processing Record 22 of Set 6 | suba
# Processing Record 23 of Set 6 | kaeo
# Processing Record 24 of Set 6 | bud
# Processing Record 25 of Set 6 | pimenta bueno
# Processing Record 26 of Set 6 | luderitz
# Processing Record 27 of Set 6 | ilo
# Processing Record 28 of Set 6 | kaitangata
# Processing Record 29 of Set 6 | semkhoz
# Processing Record 30 of Set 6 | srivardhan
# Processing Record 31 of Set 6 | sosva
# Processing Record 32 of Set 6 | iwanai
# Processing Record 33 of Set 6 | tolaga bay
# Processing Record 34 of Set 6 | marawi
# Processing Record 35 of Set 6 | san jose
# Processing Record 36 of Set 6 | tilichiki
# Processing Record 37 of Set 6 | kenai
# Processing Record 38 of Set 6 | egvekinot
# Processing Record 39 of Set 6 | magugu
# Processing Record 40 of Set 6 | usolye-sibirskoye
# Processing Record 41 of Set 6 | adeje
# Processing Record 42 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 6 | makakilo city
# Processing Record 44 of Set 6 | kavieng
# Processing Record 45 of Set 6 | monte cristi
# City not found. Skipping...
# Processing Record 46 of Set 6 | strezhevoy
# Processing Record 47 of Set 6 | saint anthony
# Processing Record 48 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 49 of Set 6 | soyo
# Processing Record 50 of Set 6 | naro moru
# Processing Record 1 of Set 7 | alekseyevka
# Processing Record 2 of Set 7 | mahebourg
# Processing Record 3 of Set 7 | terrak
# Processing Record 4 of Set 7 | sagae
# Processing Record 5 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 7 | tarakan
# Processing Record 7 of Set 7 | buncrana
# Processing Record 8 of Set 7 | raga
# Processing Record 9 of Set 7 | porto walter
# Processing Record 10 of Set 7 | bathsheba
# Processing Record 11 of Set 7 | kathu
# Processing Record 12 of Set 7 | quthing
# Processing Record 13 of Set 7 | nanpiao
# Processing Record 14 of Set 7 | sao joao da barra
# Processing Record 15 of Set 7 | tinskoy
# Processing Record 16 of Set 7 | port-cartier
# Processing Record 17 of Set 7 | fairbanks
# Processing Record 18 of Set 7 | sakaraha
# Processing Record 19 of Set 7 | emba
# Processing Record 20 of Set 7 | yumen
# Processing Record 21 of Set 7 | campoverde
# Processing Record 22 of Set 7 | evensk
# Processing Record 23 of Set 7 | waitati
# Processing Record 24 of Set 7 | kutum
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | mandurah
# Processing Record 27 of Set 7 | jamiltepec
# Processing Record 28 of Set 7 | dhidhdhoo
# Processing Record 29 of Set 7 | wanning
# Processing Record 30 of Set 7 | yellowknife
# Processing Record 31 of Set 7 | severo-yeniseyskiy
# Processing Record 32 of Set 7 | bambanglipuro
# Processing Record 33 of Set 7 | camana
# Processing Record 34 of Set 7 | kieta
# Processing Record 35 of Set 7 | kinkala
# Processing Record 36 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 7 | watsa
# Processing Record 38 of Set 7 | ardahan
# Processing Record 39 of Set 7 | adrar
# Processing Record 40 of Set 7 | tukrah
# Processing Record 41 of Set 7 | kirakira
# Processing Record 42 of Set 7 | sovetskiy
# Processing Record 43 of Set 7 | batsfjord
# Processing Record 44 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 7 | panaba
# Processing Record 46 of Set 7 | mwinilunga
# Processing Record 47 of Set 7 | grand gaube
# Processing Record 48 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 49 of Set 7 | krasnoselkup
# Processing Record 50 of Set 7 | ko samui
# Processing Record 1 of Set 8 | yar-sale
# Processing Record 2 of Set 8 | lufilufi
# Processing Record 3 of Set 8 | nyurba
# Processing Record 4 of Set 8 | guerrero negro
# Processing Record 5 of Set 8 | hanting
# Processing Record 6 of Set 8 | batagay
# Processing Record 7 of Set 8 | bemidji
# Processing Record 8 of Set 8 | weinan
# Processing Record 9 of Set 8 | hue
# Processing Record 10 of Set 8 | qandala
# Processing Record 11 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 12 of Set 8 | ternate
# Processing Record 13 of Set 8 | cayenne
# Processing Record 14 of Set 8 | marovoay
# Processing Record 15 of Set 8 | acajutla
# Processing Record 16 of Set 8 | tazovskiy
# Processing Record 17 of Set 8 | deputatskiy
# Processing Record 18 of Set 8 | hessisch lichtenau
# Processing Record 19 of Set 8 | pervomaysk
# Processing Record 20 of Set 8 | saint-michel-des-saints
# Processing Record 21 of Set 8 | freetown
# Processing Record 22 of Set 8 | sabha
# Processing Record 23 of Set 8 | zeya
# Processing Record 24 of Set 8 | auki
# Processing Record 25 of Set 8 | luebo
# Processing Record 26 of Set 8 | russell
# Processing Record 27 of Set 8 | whitianga
# Processing Record 28 of Set 8 | moron
# Processing Record 29 of Set 8 | beira
# Processing Record 30 of Set 8 | marsaxlokk
# Processing Record 31 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 8 | urusha
# Processing Record 33 of Set 8 | sorland
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | somanda
# Processing Record 36 of Set 8 | nanning
# Processing Record 37 of Set 8 | novyy urengoy
# Processing Record 38 of Set 8 | george town
# Processing Record 39 of Set 8 | taoudenni
# Processing Record 40 of Set 8 | nuuk
# Processing Record 41 of Set 8 | chuy
# Processing Record 42 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 8 | taltal
# Processing Record 44 of Set 8 | caloundra
# Processing Record 45 of Set 8 | kahului
# Processing Record 46 of Set 8 | leningradskiy
# Processing Record 47 of Set 8 | guavata
# Processing Record 48 of Set 8 | marshfield
# Processing Record 49 of Set 8 | cabedelo
# Processing Record 50 of Set 8 | booue
# Processing Record 1 of Set 9 | miri
# Processing Record 2 of Set 9 | saint-augustin
# Processing Record 3 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 9 | santana
# Processing Record 5 of Set 9 | gwadar
# Processing Record 6 of Set 9 | tagusao
# Processing Record 7 of Set 9 | lagoa
# Processing Record 8 of Set 9 | norman wells
# Processing Record 9 of Set 9 | ha giang
# Processing Record 10 of Set 9 | kamenka
# Processing Record 11 of Set 9 | port lincoln
# Processing Record 12 of Set 9 | manicore
# Processing Record 13 of Set 9 | necochea
# Processing Record 14 of Set 9 | lubango
# Processing Record 15 of Set 9 | saint-joseph
# Processing Record 16 of Set 9 | ust-kuyga
# Processing Record 17 of Set 9 | dawlatabad
# Processing Record 18 of Set 9 | olinda
# Processing Record 19 of Set 9 | tamandare
# Processing Record 20 of Set 9 | atambua
# Processing Record 21 of Set 9 | quesnel
# Processing Record 22 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 9 | miramar
# Processing Record 24 of Set 9 | chiang kham
# Processing Record 25 of Set 9 | gaoua
# Processing Record 26 of Set 9 | kemijarvi
# Processing Record 27 of Set 9 | bage
# Processing Record 28 of Set 9 | karratha
# Processing Record 29 of Set 9 | kingman
# Processing Record 30 of Set 9 | baruun-urt
# Processing Record 31 of Set 9 | tabuk
# Processing Record 32 of Set 9 | husavik
# Processing Record 33 of Set 9 | broome
# Processing Record 34 of Set 9 | sakakah
# Processing Record 35 of Set 9 | gumushane
# City not found. Skipping...
# Processing Record 36 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 9 | bayanday
# Processing Record 38 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 39 of Set 9 | huancabamba
# Processing Record 40 of Set 9 | diphu
# Processing Record 41 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 9 | kattivakkam
# Processing Record 43 of Set 9 | kerch
# Processing Record 44 of Set 9 | pangnirtung
# Processing Record 45 of Set 9 | amapa
# Processing Record 46 of Set 9 | carbonear
# Processing Record 47 of Set 9 | kikwit
# Processing Record 48 of Set 9 | clarence town
# Processing Record 49 of Set 9 | shihezi
# Processing Record 50 of Set 9 | aguas belas
# Processing Record 1 of Set 10 | matara
# Processing Record 2 of Set 10 | jilib
# Processing Record 3 of Set 10 | heihe
# Processing Record 4 of Set 10 | san rafael
# Processing Record 5 of Set 10 | poum
# Processing Record 6 of Set 10 | carlyle
# Processing Record 7 of Set 10 | apatzingan
# Processing Record 8 of Set 10 | baykit
# Processing Record 9 of Set 10 | brae
# Processing Record 10 of Set 10 | mahibadhoo
# Processing Record 11 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 10 | weinheim
# Processing Record 13 of Set 10 | nokha
# Processing Record 14 of Set 10 | lagoa vermelha
# Processing Record 15 of Set 10 | maun
# Processing Record 16 of Set 10 | bangui
# Processing Record 17 of Set 10 | billings
# Processing Record 18 of Set 10 | dalby
# Processing Record 19 of Set 10 | miles city
# Processing Record 20 of Set 10 | roscommon
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 23 of Set 10 | burnie
# Processing Record 24 of Set 10 | quang ngai
# Processing Record 25 of Set 10 | bac lieu
# Processing Record 26 of Set 10 | oum hadjer
# Processing Record 27 of Set 10 | balaipungut
# Processing Record 28 of Set 10 | the valley
# Processing Record 29 of Set 10 | vestmannaeyjar
# Processing Record 30 of Set 10 | chicama
# Processing Record 31 of Set 10 | glowno
# Processing Record 32 of Set 10 | tiksi
# Processing Record 33 of Set 10 | touros
# Processing Record 34 of Set 10 | kwinana
# Processing Record 35 of Set 10 | paamiut
# Processing Record 36 of Set 10 | north platte
# Processing Record 37 of Set 10 | dharan
# Processing Record 38 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 10 | kaohsiung
# Processing Record 40 of Set 10 | newport
# Processing Record 41 of Set 10 | bom jardim
# Processing Record 42 of Set 10 | diego de almagro
# Processing Record 43 of Set 10 | goianinha
# Processing Record 44 of Set 10 | misratah
# Processing Record 45 of Set 10 | araouane
# Processing Record 46 of Set 10 | oktyabrskoye
# Processing Record 47 of Set 10 | alice springs
# Processing Record 48 of Set 10 | antofagasta
# Processing Record 49 of Set 10 | havre-saint-pierre
# Processing Record 50 of Set 10 | gamba
# Processing Record 1 of Set 11 | santa rosa
# Processing Record 2 of Set 11 | itoman
# Processing Record 3 of Set 11 | porechye-rybnoye
# Processing Record 4 of Set 11 | puerto del rosario
# Processing Record 5 of Set 11 | yafran
# Processing Record 6 of Set 11 | alyangula
# Processing Record 7 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 11 | barkhan
# Processing Record 9 of Set 11 | tupik
# Processing Record 10 of Set 11 | sao filipe
# Processing Record 11 of Set 11 | tigil
# Processing Record 12 of Set 11 | beyneu
# Processing Record 13 of Set 11 | tilhar
# Processing Record 14 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 11 | matagami
# Processing Record 16 of Set 11 | jatai
# Processing Record 17 of Set 11 | pimentel
# Processing Record 18 of Set 11 | kamthi
# Processing Record 19 of Set 11 | kudahuvadhoo
# Processing Record 20 of Set 11 | betafo
# Processing Record 21 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 11 | aberystwyth
# Processing Record 23 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 11 | khuzdar
# Processing Record 25 of Set 11 | chernyshevskiy
# Processing Record 26 of Set 11 | halifax
# Processing Record 27 of Set 11 | nalut
# Processing Record 28 of Set 11 | hofn
# Processing Record 29 of Set 11 | fort nelson
# Processing Record 30 of Set 11 | vigrestad
# Processing Record 31 of Set 11 | arlit
# Processing Record 32 of Set 11 | beni
# Processing Record 33 of Set 11 | krasnoshchekovo
# Processing Record 34 of Set 11 | bandarbeyla
# Processing Record 35 of Set 11 | vardo
# Processing Record 36 of Set 11 | maralal
# Processing Record 37 of Set 11 | boa vista
# Processing Record 38 of Set 11 | vostok
# Processing Record 39 of Set 11 | constitucion
# Processing Record 40 of Set 11 | kokstad
# Processing Record 41 of Set 11 | karpathos
# Processing Record 42 of Set 11 | saint-georges
# Processing Record 43 of Set 11 | florianopolis
# Processing Record 44 of Set 11 | martapura
# Processing Record 45 of Set 11 | samana
# Processing Record 46 of Set 11 | narsaq
# Processing Record 47 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 11 | bartlesville
# Processing Record 49 of Set 11 | redmond
# Processing Record 50 of Set 11 | hamilton
# Processing Record 1 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 12 | mwense
# Processing Record 4 of Set 12 | nador
# Processing Record 5 of Set 12 | tornio
# Processing Record 6 of Set 12 | teseney
# Processing Record 7 of Set 12 | katherine
# Processing Record 8 of Set 12 | tokmak
# Processing Record 9 of Set 12 | burica
# City not found. Skipping...
# Processing Record 10 of Set 12 | qaracala
# Processing Record 11 of Set 12 | cabo san lucas
# Processing Record 12 of Set 12 | camopi
# Processing Record 13 of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record 14 of Set 12 | verkhnevilyuysk
# Processing Record 15 of Set 12 | novomykolayivka
# Processing Record 16 of Set 12 | lingao
# Processing Record 17 of Set 12 | bonavista
# Processing Record 18 of Set 12 | maues
# Processing Record 19 of Set 12 | yerbogachen
# Processing Record 20 of Set 12 | dubti
# Processing Record 21 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 12 | kohlu
# Processing Record 23 of Set 12 | miandrivazo
# Processing Record 24 of Set 12 | ferme-neuve
# Processing Record 25 of Set 12 | zhangjiakou
# Processing Record 26 of Set 12 | port keats
# Processing Record 27 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 12 | ruidoso
# Processing Record 29 of Set 12 | poso
# Processing Record 30 of Set 12 | turukhansk
# Processing Record 31 of Set 12 | kindu
# Processing Record 32 of Set 12 | port pirie
# Processing Record 33 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 12 | ures
# Processing Record 35 of Set 12 | mopti
# Processing Record 36 of Set 12 | tres lagoas
# Processing Record 37 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 38 of Set 12 | vizinga
# Processing Record 39 of Set 12 | norrkoping
# Processing Record 40 of Set 12 | waipawa
# Processing Record 41 of Set 12 | mehamn
# Processing Record 42 of Set 12 | luhyny
# Processing Record 43 of Set 12 | bolshoye selo
# Processing Record 44 of Set 12 | acarau
# Processing Record 45 of Set 12 | moquegua
# Processing Record 46 of Set 12 | arkhara
# Processing Record 47 of Set 12 | kalmunai
# Processing Record 48 of Set 12 | lubbock
# Processing Record 49 of Set 12 | tucurui
# Processing Record 50 of Set 12 | flores
# Processing Record 1 of Set 13 | sens
# Processing Record 2 of Set 13 | carutapera
# Processing Record 3 of Set 13 | basco
# Processing Record 4 of Set 13 | senador pompeu
# Processing Record 5 of Set 13 | bose
# Processing Record 6 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 13 | kumla
# Processing Record 8 of Set 13 | tacuarembo
# Processing Record 9 of Set 13 | belgrade
# Processing Record 10 of Set 13 | martyush
# Processing Record 11 of Set 13 | chapais
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    New Norfolk -42.7826  147.0587    284.77        56          53
# 1         Kalmar  56.6616   16.3616    270.35        90          75
# 2       Tasiilaq  65.6145  -37.6368    269.24        68          39
# 3   Punta Arenas -53.1500  -70.9167    280.21        65           0
# 4    San Ignacio  17.1561  -89.0714    293.81        95           0
# 5     Bredasdorp -34.5322   20.0403    288.82        92          92
# 6       Hermanus -34.4187   19.2345    289.15        89         100
# 7        Mildura -34.2000  142.1500    290.97        43           1
# 8  Half Moon Bay  37.4636 -122.4286    285.40        84           0
# 9   Saint George  37.1041 -113.5841    279.23        78          75
#
#    Wind Speed Country                 Date
# 0        1.34      AU  2022-12-08 01:29:59
# 1        3.58      SE  2022-12-08 01:29:59
# 2        1.88      GL  2022-12-08 01:30:01
# 3        6.69      CL  2022-12-08 01:30:01
# 4        1.25      BZ  2022-12-08 01:30:02
# 5        1.82      ZA  2022-12-08 01:30:03
# 6        4.32      ZA  2022-12-08 01:30:04
# 7        7.58      AU  2022-12-08 01:30:04
# 8        2.06      US  2022-12-08 01:30:05
# 9        1.79      US  2022-12-08 01:30:06

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

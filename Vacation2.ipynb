# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd
import geoviews

# %%
# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID         City Country                 Date      Lat       Lng  \
# 0        0     Luderitz     NaN  2022-12-09 02:56:02 -26.6481   15.1594
# 1        1       Albany      US  2022-12-09 02:54:07  42.6001  -73.9662
# 2        2         Nome      US  2022-12-09 02:53:40  64.5011 -165.4064
# 3        3  Kattivakkam      IN  2022-12-09 02:56:03  13.2167   80.3167
# 4        4        Kitui      KE  2022-12-09 02:56:03  -1.3670   38.0106
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     60.15        89           0        7.49
# 1     34.41        81          24        4.88
# 2     17.67        93         100        5.75
# 3     69.89        83         100       23.76
# 4     62.15        95         100        1.41

# %%
# Get the datatypes.
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
city_data_df.shape
# Out:
# (570, 10)

# %%
# Configure the map plot_1
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM"
)

# %%
# Display the map plot_1
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_2
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_3
map_plot_3 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Refactor the code and create a map where the point's size is given by the "Wind Speed" column. 
# Choose an appropriate scale for the points and try out a different tile.
map_plot_5 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriTerrain",
    frame_width = 700,
    frame_height = 500,
    size = "Wind Speed",
    scale = 1.5,
    color = "City"
)

# Display the map plot
map_plot_5
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Wind Speed)

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 55
# What is the maximum temperature you would like for your trip? 95

# %%
# filter the maximum temperature column in the city_data_df DataFrame using logical operators 
# to create a new DataFrame with the cities that meet the customer's criteria.
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country                 Date      Lat       Lng  \
# 0         0      Luderitz     NaN  2022-12-09 02:56:02 -26.6481   15.1594
# 3         3   Kattivakkam      IN  2022-12-09 02:56:03  13.2167   80.3167
# 4         4         Kitui      KE  2022-12-09 02:56:03  -1.3670   38.0106
# 7         7   Port Alfred      ZA  2022-12-09 02:56:04 -33.5906   26.8910
# 9         9      Villazon      BO  2022-12-09 02:56:05 -22.0866  -65.5942
# 10       10        Hobart      AU  2022-12-09 02:55:10 -42.8794  147.3294
# 11       11          Axim      GH  2022-12-09 02:56:06   4.8699   -2.2405
# 13       13    Tombouctou      ML  2022-12-09 02:56:07  20.0000   -3.0000
# 14       14  Kruisfontein      ZA  2022-12-09 02:56:08 -34.0033   24.7314
# 15       15    Kaitangata      NZ  2022-12-09 02:56:08 -46.2817  169.8464
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      60.15        89           0        7.49
# 3      69.89        83         100       23.76
# 4      62.15        95         100        1.41
# 7      73.18        94          90        4.00
# 9      55.36        56         100        6.11
# 10     61.27        72          40       11.50
# 11     77.81        85           7        6.13
# 13     72.25        16           0       10.60
# 14     66.88        93          14        6.40
# 15     60.71        72         100        5.01

# %%
preferred_cities_df.count()
# Out:
# City_ID       322
# City          322
# Country       318
# Date          322
# Lat           322
# Lng           322
# Max Temp      322
# Humidity      322
# Cloudiness    322
# Wind Speed    322
# dtype: int64

# %%
# 6.5.4
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 0       Luderitz     NaN     60.15 -26.6481   15.1594
# 3    Kattivakkam      IN     69.89  13.2167   80.3167
# 4          Kitui      KE     62.15  -1.3670   38.0106
# 7    Port Alfred      ZA     73.18 -33.5906   26.8910
# 9       Villazon      BO     55.36 -22.0866  -65.5942
# 10        Hobart      AU     61.27 -42.8794  147.3294
# 11          Axim      GH     77.81   4.8699   -2.2405
# 13    Tombouctou      ML     72.25  20.0000   -3.0000
# 14  Kruisfontein      ZA     66.88 -34.0033   24.7314
# 15    Kaitangata      NZ     60.71 -46.2817  169.8464

# %%
# Set initial parameters to search for a hotel.
from config import geoapify_key
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
}

# %%
# Import the required libraries
import requests

# Import API key
from config import geoapify_key

# %%
# Set the parameters to search for a hotel in Paris.
latitude = 48.8566
longitude = 2.3522
radius = 5000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "filter": f"circle:{longitude},{latitude},{radius}"
}

# Set up the base URL for the Geoapify Places API.
base_url = "https://api.geoapify.com/v2/places"

# Make request and retrieve the JSON data by using the params dictionary
hotels = requests.get(base_url, params=params).json()

# Display the JSON data
hotels
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Hilton Paris Opera',
#     'housenumber': '108',
#     'street': 'Rue Saint-Lazare',
#     'city_block': "Quartier de l'Europe",
#     'suburb': '8th Arrondissement of Paris',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75008',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3258962791827065,
#     'lat': 48.87572165,
#     'formatted': 'Hilton Paris Opera, 108 Rue Saint-Lazare, 75008 Paris, France',
#     'address_line1': 'Hilton Paris Opera',
#     'address_line2': '108 Rue Saint-Lazare, 75008 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access',
#      'internet_access.free'],
#     'details': ['details',
#      'details.accommodation',
#      'details.building',
#      'details.contact',
#      'details.facilities',
#      'details.payment',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'fax': '+33 1 429 30 120',
#       'name': 'Hilton Paris Opera',
#       'brand': 'Hilton',
#       'email': 'parisopera.info@hilton.com',
#       'rooms': 268,
#       'stars': 4,
#       'osm_id': -1069737,
#       'smoking': 'no',
#       'tourism': 'hotel',
#       'website': 'https://www.hilton.com/en/hotels/parophi-hilton-paris-opera/?WT.mc_id=zELWAKN0EMEA1HI2DMH3LocalSearch4DGGenericx6PAROPHI',
#       'building': 'hotel',
#       'operator': 'Hilton',
#       'osm_type': 'r',
#       'wikidata': 'Q2992084',
#       'addr:city': 'Paris',
#       'wikipedia': 'fr:Hilton Paris Opéra',
#       'roof:shape': 'mansard',
#       'addr:street': 'Rue Saint-Lazare',
#       'payment:cash': 'yes',
#       'payment:visa': 'yes',
#       'addr:postcode': 75008,
#       'brand:wikidata': 'Q598884',
#       'brand:wikipedia': 'en:Hilton Hotels & Resorts',
#       'building:levels': 6,
#       'contact:twitter': 'https://twitter.com/hiltonparisoper',
#       'internet_access': 'wlan',
#       'addr:housenumber': 108,
#       'contact:facebook': 'https://www.facebook.com/hiltonparisopera',
#       'contact:instagram': 'https://www.instagram.com/hiltonparisopera',
#       'payment:mastercard': 'yes',
#       'internet_access:fee': 'no',
#       'payment:american_express': 'yes'}},
#     'place_id': '517b5a9bd98a9a024059c67f77d917704840f00101f901a95210000000000092031248696c746f6e205061726973204f70657261'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.325460147908698, 48.87572782835882]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel de Pourtalès',
#     'street': 'Marché de la Madeleine',
#     'city_block': 'Quartier de la Madeleine',
#     'suburb': '8th Arrondissement of Paris',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75008',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.325198933610457,
#     'lat': 48.8714529,
#     'formatted': 'Hôtel de Pourtalès, Marché de la Madeleine, 75008 Paris, France',
#     'address_line1': 'Hôtel de Pourtalès',
#     'address_line2': 'Marché de la Madeleine, 75008 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation'],
#     'details': ['details', 'details.contact', 'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hôtel de Pourtalès',
#       'email': 'jaayme@groupe-allard.com',
#       'phone': '+33 6 38 65 93 79',
#       'osm_id': 67561484,
#       'tourism': 'hotel',
#       'website': 'http://noaddresshotels.com/',
#       'alt_name': 'No Address Hotel',
#       'building': 'yes',
#       'osm_type': 'w',
#       'wikidata': 'Q3145934',
#       'wikipedia': 'fr:Hôtel de Pourtalès'}},
#     'place_id': '51a8e74008c599024059e6a424228c6f4840f00102f9010ce806040000000092031448c3b474656c20646520506f757274616cc3a873'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3250828404242903, 48.8714640311171]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel Caumartin Opéra',
#     'housenumber': '27',
#     'street': 'Rue de Caumartin',
#     'city_block': "Quartier de la Chaussée-d'Antin",
#     'suburb': '9th Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75009',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3278632342293655,
#     'lat': 48.8717109,
#     'formatted': 'Hôtel Caumartin Opéra, 27 Rue de Caumartin, 75009 Paris, France',
#     'address_line1': 'Hôtel Caumartin Opéra',
#     'address_line2': '27 Rue de Caumartin, 75009 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hôtel Caumartin Opéra',
#       'brand': 'Astotel',
#       'phone': '+33 147429595',
#       'stars': 3,
#       'osm_id': 69226757,
#       'tourism': 'hotel',
#       'website': 'https://www.astotel.com/hotel/hotel-caumartin-opera/',
#       'building': 'yes',
#       'osm_type': 'w',
#       'addr:street': 'Rue de Caumartin',
#       'addr:postcode': 75009,
#       'opening_hours': '24/7',
#       'internet_access': 'wlan',
#       'addr:housenumber': 27,
#       'award:hotelstars': 3}},
#     'place_id': '518b9c96f0779f02405908e3021d946f4840f00102f901055120040000000092031748c3b474656c204361756d617274696e204f70c3a97261'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3278654857600194, 48.87170755997619]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel Rochechouart',
#     'old_name': "Carlton's",
#     'street': 'Rue Lallier',
#     'city_block': 'Quartier de Rochechouart',
#     'suburb': '9th Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75009',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3409765785262207,
#     'lat': 48.88194565,
#     'formatted': 'Hôtel Rochechouart, Rue Lallier, 75009 Paris, France',
#     'address_line1': 'Hôtel Rochechouart',
#     'address_line2': 'Rue Lallier, 75009 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'building.catering',
#      'catering',
#      'catering.restaurant',
#      'catering.restaurant.french'],
#     'details': ['details',
#      'details.building',
#      'details.catering',
#      'details.contact',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hôtel Rochechouart',
#       'email': 'bonjour@hotelrochechouart.com',
#       'phone': '+33 1 42 81 91 00',
#       'osm_id': 69417387,
#       'amenity': 'restaurant',
#       'cuisine': 'french',
#       'tourism': 'hotel',
#       'website': 'https://www.hotelrochechouart.com',
#       'building': 'yes',
#       'facebook': 'https://www.facebook.com/hotelrochechouart',
#       'old_name': "Carlton's",
#       'osm_type': 'w',
#       'wikidata': 'Q3145947',
#       'wikipedia': 'fr:Hôtel de Rochechouart',
#       'building:levels': 6}},
#     'place_id': '510b7eb9195aba024059b132acf1e2704840f00102f901ab3923040000000092031348c3b474656c20526f63686563686f75617274'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.340992165540006, 48.88192578228098]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel Elysées Céramic',
#     'old_name': 'Céramic Hôtel',
#     'street': 'Villa Nouvelle',
#     'city_block': 'Quartier du Faubourg-du-Roule',
#     'suburb': '8th Arrondissement of Paris',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75008',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.2976855242212273,
#     'lat': 48.87677085,
#     'formatted': 'Hôtel Elysées Céramic, Villa Nouvelle, 75008 Paris, France',
#     'address_line1': 'Hôtel Elysées Céramic',
#     'address_line2': 'Villa Nouvelle, 75008 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'building.historic',
#      'building.residential',
#      'heritage'],
#     'details': ['details',
#      'details.accommodation',
#      'details.building',
#      'details.contact',
#      'details.facilities',
#      'details.heritage',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'fax': '+33 1 46 22 95 83',
#       'name': 'Hôtel Elysées Céramic',
#       'email': 'info@elysees-ceramic.com',
#       'phone': '+33 1 42 27 20 30',
#       'stars': 3,
#       'osm_id': 70224059,
#       'ref:mhs': 'PA00088808',
#       'tourism': 'hotel',
#       'website': 'https://www.ceramic-paris-hotel.com/',
#       'building': 'apartments',
#       'heritage': 3,
#       'old_name': 'Céramic Hôtel',
#       'osm_type': 'w',
#       'wikidata': 'Q3010267',
#       'architect': 'J. Lavirotte',
#       'wikipedia': 'fr:Céramic Hôtel',
#       'start_date': 1904,
#       'wheelchair': 'no',
#       'contact:city': 'Paris',
#       'contact:street': 'Avenue de Wagram',
#       'building:levels': 8,
#       'contact:postcode': 75008,
#       'heritage:operator': 'mhs',
#       'architect:wikidata': 'Q3188718',
#       'contact:housenumber': 34,
#       'mhs:inscription_date': '1964-07-17'}},
#     'place_id': '51660793d5b7610240595a2573363a704840f00102f901bb882f040000000092031848c3b474656c20456c7973c3a965732043c3a972616d6963'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.297713917302576, 48.876776510451876]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel Concorde Montparnasse',
#     'housenumber': '40',
#     'street': 'Rue du Commandant René Mouchotte',
#     'city_block': 'Quartier de Plaisance',
#     'neighbourhood': '14th Arrondissement',
#     'suburb': 'Paris',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75014',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.31836851875,
#     'lat': 48.83788835,
#     'formatted': 'Hôtel Concorde Montparnasse, 40 Rue du Commandant René Mouchotte, 75014 Paris, France',
#     'address_line1': 'Hôtel Concorde Montparnasse',
#     'address_line2': '40 Rue du Commandant René Mouchotte, 75014 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities',
#      'details.payment'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'fax': '+33 1 56 54 84 84',
#       'name': 'Hôtel Concorde Montparnasse',
#       'brand': 'Ferré Hotels',
#       'email': 'cdb@hotel-montparnasse-hotel.com',
#       'phone': '+33 1 56 54 84 00',
#       'rooms': 352,
#       'stars': 4,
#       'osm_id': 79688704,
#       'tourism': 'hotel',
#       'website': 'https://www.hotel-montparnasse.com/',
#       'osm_type': 'w',
#       'addr:city': 'Paris',
#       'wheelchair': 'yes',
#       'addr:street': 'Rue du Commandant René Mouchotte',
#       'payment:cash': 'yes',
#       'payment:visa': 'yes',
#       'addr:postcode': 75014,
#       'opening_hours': 'Mo-Su,PH 00:00-00:00',
#       'internet_access': 'wlan',
#       'addr:housenumber': 40,
#       'air_conditioning': 'yes',
#       'payment:mastercard': 'yes',
#       'internet_access:fee': 'no',
#       'opening_hours:covid19': 'Mo-Su,PH 00:00-00:00',
#       'payment:american_express': 'yes'}},
#     'place_id': '5199fe69fefb8b02405994cde8c33f6b4840f00102f90100f4bf040000000092031c48c3b474656c20436f6e636f726465204d6f6e747061726e61737365'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.318351733789154, 48.8378834616407]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Bains Paris',
#     'old_name': 'Les Bains Douches',
#     'housenumber': '7',
#     'street': "Rue du Bourg l'Abbé",
#     'city_block': 'Quartier Sainte-Avoye',
#     'suburb': '3rd Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75003',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3520023,
#     'lat': 48.8639163,
#     'formatted': "Les Bains Paris, 7 Rue du Bourg l'Abbé, 75003 Paris, France",
#     'address_line1': 'Les Bains Paris',
#     'address_line2': "7 Rue du Bourg l'Abbé, 75003 Paris, France",
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'catering',
#      'catering.restaurant'],
#     'details': ['details', 'details.contact', 'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Les Bains Paris',
#       'phone': '+33 1 42 77 07 07',
#       'osm_id': 706168394,
#       'amenity': 'restaurant',
#       'tourism': 'hotel',
#       'website': 'https://lesbains-paris.com',
#       'old_name': 'Les Bains Douches',
#       'osm_type': 'n',
#       'wikidata': 'Q3230922',
#       'addr:city': 'Paris',
#       'amenity_1': 'nightclub',
#       'wikipedia': 'fr:Les Bains Douches',
#       'short_name': 'Les Bains',
#       'addr:street': "Rue du Bourg l'Abbé",
#       'addr:postcode': 75003,
#       'addr:housenumber': 7}},
#     'place_id': '512beff494e6d002405905e72ecf946e4840f00103f9014a46172a0000000092030f4c6573204261696e73205061726973'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3520023, 48.86391629972608]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Best Western Premier Le Swann',
#     'street': 'Rue de Naples',
#     'city_block': "Quartier de l'Europe",
#     'suburb': '8th Arrondissement of Paris',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75008',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3206849,
#     'lat': 48.8797757,
#     'formatted': 'Best Western Premier Le Swann, Rue de Naples, 75008 Paris, France',
#     'address_line1': 'Best Western Premier Le Swann',
#     'address_line2': 'Rue de Naples, 75008 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'fax': '+33 1 45 22 97 15',
#       'name': 'Best Western Premier Le Swann',
#       'brand': 'Best Western',
#       'email': 'reservation@hotel-leswann.com',
#       'phone': '+33 1 45 22 80 80',
#       'stars': 4,
#       'osm_id': 1214588638,
#       'tourism': 'hotel',
#       'website': 'https://www.hotel-leswann.com/',
#       'operator': 'Best Western',
#       'osm_type': 'n',
#       'wikidata': 'Q56600367',
#       'brand:wikidata': 'Q830334',
#       'brand:wikipedia': 'en:Best Western',
#       'internet_access': 'wlan',
#       'internet_access:fee': 'no'}},
#     'place_id': '517891ae3ec390024059a20f797d9c704840f00103f901de2665480000000092031d42657374205765737465726e205072656d696572204c65205377616e6e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3206849, 48.879775699722146]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Shangri-La Hotel',
#     'old_name': 'Hôtel particulier de Roland Bonaparte',
#     'housenumber': '10',
#     'street': "Avenue d'Iéna",
#     'city_block': 'Quartier de Chaillot',
#     'suburb': '16th Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75116',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.2934262,
#     'lat': 48.8637194,
#     'formatted': "Shangri-La Hotel, 10 Avenue d'Iéna, 75116 Paris, France",
#     'address_line1': 'Shangri-La Hotel',
#     'address_line2': "10 Avenue d'Iéna, 75116 Paris, France",
#     'categories': ['accommodation', 'accommodation.hotel', 'heritage'],
#     'details': ['details',
#      'details.contact',
#      'details.heritage',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Shangri-La Hotel',
#       'phone': '+33 1 53 67 19 98',
#       'osm_id': 2188238939,
#       'ref:mhs': 'PA75160005',
#       'tourism': 'hotel',
#       'website': 'https://www.shangri-la.com/paris',
#       'heritage': 3,
#       'old_name': 'Hôtel particulier de Roland Bonaparte',
#       'osm_type': 'n',
#       'wikidata': 'Q3481407',
#       'wikipedia': 'fr:Hôtel particulier de Roland Bonaparte',
#       'addr:street': "Avenue d'Iéna",
#       'addr:housenumber': 10,
#       'heritage:operator': 'mhs',
#       'mhs:inscription_date': '2009-02-10'}},
#     'place_id': '510151e6d5ef580240594b5f775b8e6e4840f00103f9015be06d82000000009203105368616e6772692d4c6120486f74656c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.2934261999999994, 48.86371939972613]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Timhotel Nation',
#     'housenumber': '5-7',
#     'street': "Rue d'Avron",
#     'suburb': 'Quartier de Charonne',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75020',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3989998,
#     'lat': 48.8515323,
#     'formatted': "Timhotel Nation, 5-7 Rue d'Avron, 75020 Paris, France",
#     'address_line1': 'Timhotel Nation',
#     'address_line2': "5-7 Rue d'Avron, 75020 Paris, France",
#     'categories': ['accommodation', 'accommodation.hotel', 'internet_access'],
#     'details': ['details', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Timhotel Nation',
#       'brand': 'Timhotel',
#       'phone': '+33 1 43 56 29 29',
#       'osm_id': 2290025377,
#       'tourism': 'hotel',
#       'website': 'https://www.timhotel-paris-nation.fr',
#       'osm_type': 'n',
#       'addr:city': 'Paris',
#       'addr:street': "Rue d'Avron",
#       'addr:country': 'FR',
#       'addr:postcode': 75020,
#       'opening_hours': '24/7',
#       'internet_access': 'wlan',
#       'addr:housenumber': '5-7'}},
#     'place_id': '5163e2a0ce26310340598669a902ff6c4840f00103f901a1037f880000000092030f54696d686f74656c204e6174696f6e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3989998, 48.85153229972916]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Paris Montmartre Hôtel',
#     'housenumber': '17',
#     'street': 'Rue Biot',
#     'suburb': 'Quartier des Batignolles',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75017',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3257947,
#     'lat': 48.8845083,
#     'formatted': 'Paris Montmartre Hôtel, 17 Rue Biot, 75017 Paris, France',
#     'address_line1': 'Paris Montmartre Hôtel',
#     'address_line2': '17 Rue Biot, 75017 Paris, France',
#     'categories': ['accommodation', 'accommodation.hotel', 'internet_access'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Paris Montmartre Hôtel',
#       'email': 'info@hoteldeparis-montmartre.com',
#       'phone': '+33 1 42 94 02 50',
#       'stars': 3,
#       'osm_id': 2383470348,
#       'tourism': 'hotel',
#       'website': 'https://www.hoteldeparis-montmartre.com/',
#       'osm_type': 'n',
#       'addr:street': 'Rue Biot',
#       'addr:postcode': 75017,
#       'opening_hours': '24/7',
#       'internet_access': 'wlan',
#       'addr:housenumber': 17}},
#     'place_id': '5159ae6d403a9b024059c92b669137714840f00103f9010cdf108e000000009203175061726973204d6f6e746d61727472652048c3b474656c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3257947, 48.884508299720956]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Timhotel',
#     'housenumber': '8',
#     'street': "Rue d'Odessa",
#     'city_block': 'Quartier du Montparnasse',
#     'neighbourhood': '14th Arrondissement',
#     'suburb': 'Paris',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75014',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3243275,
#     'lat': 48.8425624,
#     'formatted': "Timhotel, 8 Rue d'Odessa, 75014 Paris, France",
#     'address_line1': 'Timhotel',
#     'address_line2': "8 Rue d'Odessa, 75014 Paris, France",
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free'],
#     'details': ['details', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Timhotel',
#       'email': 'montparnasse@timhotel.com',
#       'phone': '+33 1 45 48 96 62',
#       'osm_id': 2894346401,
#       'smoking': 'separated',
#       'tourism': 'hotel',
#       'website': 'https://www.timhotel.com/fr/timhotel-paris-gare-montparnasse-3_9',
#       'osm_type': 'n',
#       'addr:city': 'Paris',
#       'addr:street': "Rue d'Odessa",
#       'opening_hours': '24/7',
#       'internet_access': 'wlan',
#       'addr:housenumber': 8,
#       'internet_access:fee': 'no'}},
#     'place_id': '51298c2d043998024059c1d7af15d96b4840f00103f901a13884ac0000000092030854696d686f74656c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3243274999999994, 48.842562399731385]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel des Métallos',
#     'street': 'Rue de la Folie-Méricourt',
#     'city_block': 'Quartier Saint-Ambroise',
#     'suburb': '11th Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75011',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3719442,
#     'lat': 48.8640715,
#     'formatted': 'Hôtel des Métallos, Rue de la Folie-Méricourt, 75011 Paris, France',
#     'address_line1': 'Hôtel des Métallos',
#     'address_line2': 'Rue de la Folie-Méricourt, 75011 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'fax': '+33 1 43 38 66 13',
#       'name': 'Hôtel des Métallos',
#       'email': 'contact@hoteldesmetallos.com',
#       'phone': '+33 1 43 38 73 63',
#       'rooms': 30,
#       'osm_id': 3654530602,
#       'smoking': 'no',
#       'tourism': 'hotel',
#       'website': 'http://www.hoteldesmetallos.com',
#       'facebook': 'https://www.facebook.com/H%C3%B4tel-des-M%C3%A9tallos-395320123857951/',
#       'osm_type': 'n',
#       'wheelchair': 'yes',
#       'opening_hours': '24/7',
#       'contact:street': 'Rue de la Folie Méricourt',
#       'internet_access': 'wlan',
#       'contact:housenumber': 50,
#       'internet_access:fee': 'no',
#       'internet_access:ssid': 'Hotel_des_Metallos'}},
#     'place_id': '51bd7e77e1bdf90240594f5d18e5996e4840f00103f9012ab6d3d90000000092031448c3b474656c20646573204dc3a974616c6c6f73'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3719442, 48.86407149972603]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel Suites Unic Renoir Saint-Germain',
#     'housenumber': '56',
#     'street': 'Rue du Montparnasse',
#     'city_block': 'Quartier du Montparnasse',
#     'neighbourhood': '14th Arrondissement',
#     'suburb': 'Paris',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75014',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3254084,
#     'lat': 48.8420516,
#     'formatted': 'Hôtel Suites Unic Renoir Saint-Germain, 56 Rue du Montparnasse, 75014 Paris, France',
#     'address_line1': 'Hôtel Suites Unic Renoir Saint-Germain',
#     'address_line2': '56 Rue du Montparnasse, 75014 Paris, France',
#     'categories': ['accommodation', 'accommodation.hotel', 'internet_access'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hôtel Suites Unic Renoir Saint-Germain',
#       'email': 'unic.hotel@wanadoo.fr',
#       'phone': '+33 1 43 20 96 04',
#       'rooms': 45,
#       'stars': 3,
#       'osm_id': 4110680890,
#       'tourism': 'hotel',
#       'website': 'https://www.hotel-unic.com/',
#       'osm_type': 'n',
#       'addr:street': 'Rue du Montparnasse',
#       'opening_hours': '24/7',
#       'internet_access': 'wlan',
#       'addr:housenumber': 56,
#       'air_conditioning': 'yes'}},
#     'place_id': '51dfbf1eb86f9a0240591632c958c86b4840f00103f9013a0304f50000000092032748c3b474656c2053756974657320556e69632052656e6f6972205361696e742d4765726d61696e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3254084, 48.842051599731505]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Aparthotel Adagio Paris Opera',
#     'housenumber': '43',
#     'street': 'Rue de Caumartin',
#     'city_block': "Quartier de la Chaussée-d'Antin",
#     'suburb': '9th Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75009',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3281715,
#     'lat': 48.8728329,
#     'formatted': 'Aparthotel Adagio Paris Opera, 43 Rue de Caumartin, 75009 Paris, France',
#     'address_line1': 'Aparthotel Adagio Paris Opera',
#     'address_line2': '43 Rue de Caumartin, 75009 Paris, France',
#     'categories': ['accommodation', 'accommodation.hotel', 'internet_access'],
#     'details': ['details', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Aparthotel Adagio Paris Opera',
#       'brand': 'Adagio',
#       'phone': '+33158180820',
#       'osm_id': 4119084200,
#       'name:zh': '巴黎阿德吉奥巴黎歌剧院酒店',
#       'tourism': 'hotel',
#       'website': 'https://www.adagio-city.com/gb/home/index.shtml',
#       'osm_type': 'n',
#       'addr:city': 'Paris',
#       'addr:street': 'Rue de Caumartin',
#       'opening_hours': '24/7',
#       'brand:wikidata': 'Q2823880',
#       'brand:wikipedia': 'fr:Adagio Aparthotel',
#       'internet_access': 'wlan',
#       'addr:housenumber': 43}},
#     'place_id': '5188d51f6118a0024059ea970bfdb86f4840f00103f901a83c84f50000000092031d4170617274686f74656c2041646167696f205061726973204f70657261'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3281715, 48.87283289972386]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel Paris Villette',
#     'housenumber': '56',
#     'street': 'Rue Curial',
#     'suburb': 'Quartier de la Villette',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75019',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3731031,
#     'lat': 48.892959,
#     'formatted': 'Hôtel Paris Villette, 56 Rue Curial, 75019 Paris, France',
#     'address_line1': 'Hôtel Paris Villette',
#     'address_line2': '56 Rue Curial, 75019 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'fax': '+33140370225',
#       'name': 'Hôtel Paris Villette',
#       'email': 'hotel@parisvillette.com',
#       'phone': '+33140375074',
#       'rooms': 44,
#       'stars': 2,
#       'osm_id': 5101320813,
#       'smoking': 'outside',
#       'tourism': 'hotel',
#       'website': 'https://www.parisvillette.com/',
#       'osm_type': 'n',
#       'addr:city': 'Paris',
#       'addr:street': 'Rue Curial',
#       'addr:postcode': 75019,
#       'opening_hours': '24/7',
#       'internet_access': 'wlan',
#       'addr:housenumber': 56,
#       'internet_access:fee': 'no',
#       'internet_access:ssid': 'ParisVilletteFreebox'}},
#     'place_id': '512b4a647a1dfc024059103b027b4c724840f00103f9016dfa0f300100000092031548c3b474656c2050617269732056696c6c65747465'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3731030999999994, 48.89295899971887]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Le Grand Quartier',
#     'housenumber': '15',
#     'street': 'Rue de Nancy',
#     'city_block': 'Quartier de la Porte-Saint-Martin',
#     'suburb': '10th Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75010',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3583483,
#     'lat': 48.872047,
#     'formatted': 'Le Grand Quartier, 15 Rue de Nancy, 75010 Paris, France',
#     'address_line1': 'Le Grand Quartier',
#     'address_line2': '15 Rue de Nancy, 75010 Paris, France',
#     'categories': ['accommodation', 'accommodation.hotel', 'internet_access'],
#     'details': ['details',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Le Grand Quartier',
#       'email': 'bonjour@legrandquartier.com',
#       'phone': '+33 1 76 21 61 61',
#       'osm_id': 9762289342,
#       'tourism': 'hotel',
#       'website': 'https://www.legrandquartier.com/',
#       'osm_type': 'n',
#       'wikidata': 'Q112016427',
#       'addr:street': 'Rue de Nancy',
#       'internet_access': 'wlan',
#       'addr:housenumber': 15}},
#     'place_id': '51189ea8b6e5dd024059e331703c9f6f4840f00103f901beb6e045020000009203114c65204772616e64205175617274696572'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3583482999999994, 48.872046999724056]}},
#   {'type': 'Feature',
#    'properties': {'name': "Terrass'hôtel",
#     'housenumber': '12-14',
#     'street': 'Rue Joseph de Maistre',
#     'city_block': 'Quartier des Grandes-Carrières',
#     'suburb': '18th Arrondissement',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75018',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.333045,
#     'lat': 48.8865811,
#     'formatted': 'Terrass’’ Hôtel, 12-14 Rue Joseph de Maistre, 75018 Paris, France',
#     'address_line1': 'Terrass’’ Hôtel',
#     'address_line2': '12-14 Rue Joseph de Maistre, 75018 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'bar': 'yes',
#       'name': "Terrass'hôtel",
#       'email': 'concierge@terrass-hotel.com',
#       'image': 'https://www.terrass-hotel.com/sites/default/files/styles/1-2-free_breakpoints_theme_terrass_retina_1x/public/Hebergement/Bielsa-Studio-Artiste-Eiffel-2.jpg?itok=HXxCuNuE',
#       'phone': '+33 1 46 06 72 85',
#       'rooms': 92,
#       'stars': 4,
#       'osm_id': 253007453,
#       'name:en': 'Terrass’’ Hôtel',
#       'name:fr': 'Terrass’’ Hôtel',
#       'smoking': 'no',
#       'tourism': 'hotel',
#       'website': 'https://www.terrass-hotel.com/',
#       'osm_type': 'n',
#       'wheelchair': 'yes',
#       'addr:street': 'Rue Joseph de Maistre',
#       'description': "Construit en 1911, le Terrass'' Hotel est depuis plus d'un siècle l'un des lieux phares de Montmartre. A quelques ruelles pavées du Sacré-Cœur, ressentez l'atmosphère typique et charmante de l'un des quartiers les plus iconiques de Paris.",
#       'reservation': 'yes',
#       'addr:postcode': 75018,
#       'internet_access': 'wlan',
#       'addr:housenumber': '12-14',
#       'air_conditioning': 'yes',
#       'internet_access:fee': 'no'}},
#     'place_id': '5142c5387f13aa02405988464e7d7b714840f00103f9015d96140f0000000092030e546572726173732768c3b474656c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3330449999999994, 48.886581099720445]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Artus Hotel',
#     'housenumber': '34',
#     'street': 'Rue de Buci',
#     'suburb': 'Quartier de Saint-Germain-des-Prés',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75006',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3360798,
#     'lat': 48.8534652,
#     'formatted': 'Artus Hotel, 34 Rue de Buci, 75006 Paris, France',
#     'address_line1': 'Artus Hotel',
#     'address_line2': '34 Rue de Buci, 75006 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Artus Hotel',
#       'email': 'info@artushotel.com',
#       'image': 'https://www.artushotel.com/sites/artushotel.com/files/styles/3-4-1_breakpoints_theme_terrass_retina_1x/public/Artus%20Hotel%20classique.jpg?itok=vqPP7jxk',
#       'phone': '+33 1 43 29 07 20',
#       'rooms': 27,
#       'stars': 4,
#       'osm_id': 806100029,
#       'smoking': 'no',
#       'tourism': 'hotel',
#       'website': 'https://www.artushotel.com/',
#       'osm_type': 'n',
#       'addr:city': 'Paris',
#       'wheelchair': 'yes',
#       'addr:street': 'Rue de Buci',
#       'description': "Situé Rive Gauche en plein cœur de Saint-Germain-des-Prés, l’Hôtel Artus dévoile une atmosphère aussi chaleureuse que sophistiquée. Auréolé de 4 étoiles, l'hôtel parisien revisite avec élégance le style décoratif des années 50.",
#       'reservation': 'yes',
#       'addr:postcode': 75006,
#       'internet_access': 'wlan',
#       'addr:housenumber': 34,
#       'air_conditioning': 'yes',
#       'toilets:wheelchair': 'yes',
#       'internet_access:fee': 'no'}},
#     'place_id': '510fc52e9b4ab0024059eb8d00593e6d4840f00103f9013d1c0c300000000092030b417274757320486f74656c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3360798, 48.85346519972867]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bourgogne et Montana Hôtel',
#     'housenumber': '3',
#     'street': 'Rue de Bourgogne',
#     'suburb': 'Quartier des Invalides',
#     'district': 'Paris',
#     'city': 'Paris',
#     'state': 'Ile-de-France',
#     'region': 'Metropolitan France',
#     'postcode': '75007',
#     'country': 'France',
#     'country_code': 'fr',
#     'lon': 2.3183179,
#     'lat': 48.860154,
#     'formatted': 'Bourgogne et Montana Hôtel, 3 Rue de Bourgogne, 75007 Paris, France',
#     'address_line1': 'Bourgogne et Montana Hôtel',
#     'address_line2': '3 Rue de Bourgogne, 75007 Paris, France',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Bourgogne et Montana Hôtel',
#       'email': 'bmontana@bourgogne-montana.com',
#       'image': 'https://www.bourgogne-montana.com/sites/bourgogne-montana.com/files/styles/3-4-1_breakpoints_theme_terrass_retina_1x/public/Hebergement/Chambre%20Exclusive.jpg?itok=T0KiXoLt',
#       'phone': '+33 1 45 51 20 22',
#       'rooms': 31,
#       'stars': 4,
#       'osm_id': 914052820,
#       'smoking': 'no',
#       'tourism': 'hotel',
#       'website': 'https://www.bourgogne-montana.com/',
#       'osm_type': 'n',
#       'addr:city': 'Paris',
#       'wheelchair': 'yes',
#       'addr:street': 'Rue de Bourgogne',
#       'description': "Au cœur du très chic 7ème arrondissement, à proximité du Musée d’Orsay, de Saint-Germain-des-Prés et de la Concorde, un joyau réserve ses splendeurs aux seuls initiés : l'Hôtel Bourgogne & Montana. Admirable demeure de l’élite parisienne, cet hôtel partic",
#       'reservation': 'yes',
#       'addr:postcode': 75007,
#       'internet_access': 'wlan',
#       'addr:housenumber': 3,
#       'air_conditioning': 'yes',
#       'toilets:wheelchair': 'yes',
#       'internet_access:fee': 'no'}},
#     'place_id': '51e6d95141ea8b024059ee2cb986196e4840f00103f901d4567b360000000092031b426f7572676f676e65206574204d6f6e74616e612048c3b474656c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [2.3183178999999994, 48.86015399972699]}}]}

# %%
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"

    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Get the first hotel from the results and store the name
try:
    hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
except (KeyError, IndexError):
    # If no hotel is found, set the hotel name as "No hotel found".
    hotel_df.loc[index, "Hotel Name"] = "No hotel found"

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)

# %%
hotel_df.shape
# Out:
# (322, 6)

# %%
hotel_df.index
# Out:
# Int64Index([  0,   3,   4,   7,   9,  10,  11,  13,  14,  15,
#             ...
#             551, 553, 557, 558, 559, 560, 563, 564, 566, 567],
#            dtype='int64', length=322)

# %%
hotel_df.head()
# Out:
#           City Country  Max Temp      Lat      Lng Hotel Name
# 0     Luderitz     NaN     60.15 -26.6481  15.1594
# 3  Kattivakkam      IN     69.89  13.2167  80.3167
# 4        Kitui      KE     62.15  -1.3670  38.0106
# 7  Port Alfred      ZA     73.18 -33.5906  26.8910
# 9     Villazon      BO     55.36 -22.0866 -65.5942

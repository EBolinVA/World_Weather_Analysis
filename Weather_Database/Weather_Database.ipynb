# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["main"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Desc": city_description,
                          "Date": city_date})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port blair
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | dakar
# Processing Record 7 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 1 | tuatapere
# Processing Record 9 of Set 1 | itarema
# Processing Record 10 of Set 1 | mapiripan
# Processing Record 11 of Set 1 | khudumelapye
# Processing Record 12 of Set 1 | contamana
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | rudnogorsk
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | husavik
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | karratha
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | pangkalanbuun
# Processing Record 24 of Set 1 | westport
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | sosnovo-ozerskoye
# Processing Record 29 of Set 1 | hobyo
# Processing Record 30 of Set 1 | arlit
# Processing Record 31 of Set 1 | naryan-mar
# Processing Record 32 of Set 1 | biltine
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | dogondoutchi
# Processing Record 38 of Set 1 | gari
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | lynn haven
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | hambantota
# Processing Record 48 of Set 1 | quatre cocos
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | guazapa
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | lagoa
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | poya
# Processing Record 7 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | abbeville
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | solnechnyy
# Processing Record 16 of Set 2 | abaza
# Processing Record 17 of Set 2 | havoysund
# Processing Record 18 of Set 2 | mount isa
# Processing Record 19 of Set 2 | tasiilaq
# Processing Record 20 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | vostok
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | vuktyl
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | khuldabad
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | hofn
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | richards bay
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | aquiraz
# Processing Record 37 of Set 2 | yeppoon
# Processing Record 38 of Set 2 | ocos
# Processing Record 39 of Set 2 | pajapan
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 2 | agirish
# Processing Record 43 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 2 | broken hill
# Processing Record 45 of Set 2 | beringovskiy
# Processing Record 46 of Set 2 | varhaug
# Processing Record 47 of Set 2 | giyani
# Processing Record 48 of Set 2 | berlevag
# Processing Record 49 of Set 2 | meadow lake
# Processing Record 50 of Set 2 | mancora
# Processing Record 1 of Set 3 | constitucion
# Processing Record 2 of Set 3 | leningradskiy
# Processing Record 3 of Set 3 | teguise
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | cuiluan
# Processing Record 6 of Set 3 | escanaba
# Processing Record 7 of Set 3 | meulaboh
# Processing Record 8 of Set 3 | vallenar
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | aloleng
# Processing Record 11 of Set 3 | mareeba
# Processing Record 12 of Set 3 | pacific grove
# Processing Record 13 of Set 3 | saint-joseph
# Processing Record 14 of Set 3 | praya
# Processing Record 15 of Set 3 | itaituba
# Processing Record 16 of Set 3 | maceio
# Processing Record 17 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 3 | umm jarr
# City not found. Skipping...
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | mildura
# Processing Record 21 of Set 3 | san patricio
# Processing Record 22 of Set 3 | muros
# Processing Record 23 of Set 3 | comodoro rivadavia
# Processing Record 24 of Set 3 | tevaitoa
# Processing Record 25 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 3 | los llanos de aridane
# Processing Record 27 of Set 3 | rock springs
# Processing Record 28 of Set 3 | mayo
# Processing Record 29 of Set 3 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | pasni
# Processing Record 32 of Set 3 | thunder bay
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | taltal
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | takoradi
# Processing Record 42 of Set 3 | novyy oskol
# Processing Record 43 of Set 3 | warrnambool
# Processing Record 44 of Set 3 | zeya
# Processing Record 45 of Set 3 | kawalu
# Processing Record 46 of Set 3 | baruun-urt
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | srednekolymsk
# Processing Record 49 of Set 3 | ahipara
# Processing Record 50 of Set 3 | pevek
# Processing Record 1 of Set 4 | mogadishu
# Processing Record 2 of Set 4 | amga
# Processing Record 3 of Set 4 | the valley
# Processing Record 4 of Set 4 | port hardy
# Processing Record 5 of Set 4 | deming
# Processing Record 6 of Set 4 | soyo
# Processing Record 7 of Set 4 | chapais
# Processing Record 8 of Set 4 | olafsvik
# Processing Record 9 of Set 4 | kochubey
# Processing Record 10 of Set 4 | pisco
# Processing Record 11 of Set 4 | kachug
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | opuwo
# Processing Record 14 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 15 of Set 4 | morehead
# Processing Record 16 of Set 4 | oktyabrskoye
# Processing Record 17 of Set 4 | te anau
# Processing Record 18 of Set 4 | ambon
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | bandarbeyla
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | presidencia roque saenz pena
# Processing Record 24 of Set 4 | qaqortoq
# Processing Record 25 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 4 | veracruz
# Processing Record 27 of Set 4 | atambua
# Processing Record 28 of Set 4 | kattivakkam
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | lavrentiya
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | bontang
# Processing Record 33 of Set 4 | abhar
# Processing Record 34 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 4 | tiarei
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | saint-dizier
# Processing Record 39 of Set 4 | porto santo
# Processing Record 40 of Set 4 | flinders
# Processing Record 41 of Set 4 | eureka
# Processing Record 42 of Set 4 | korla
# Processing Record 43 of Set 4 | basco
# Processing Record 44 of Set 4 | sudbury
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | shubarshi
# Processing Record 47 of Set 4 | fortuna
# Processing Record 48 of Set 4 | gimbi
# Processing Record 49 of Set 4 | mount gambier
# Processing Record 50 of Set 4 | glendive
# Processing Record 1 of Set 5 | raciborz
# Processing Record 2 of Set 5 | cockburn town
# Processing Record 3 of Set 5 | sakaiminato
# Processing Record 4 of Set 5 | kisangani
# Processing Record 5 of Set 5 | norman wells
# Processing Record 6 of Set 5 | lujan
# Processing Record 7 of Set 5 | san cristobal
# Processing Record 8 of Set 5 | rio rancho
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 5 | aklavik
# Processing Record 12 of Set 5 | coos bay
# Processing Record 13 of Set 5 | orcopampa
# Processing Record 14 of Set 5 | mercedes
# Processing Record 15 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 5 | gat
# Processing Record 17 of Set 5 | cidreira
# Processing Record 18 of Set 5 | hualmay
# Processing Record 19 of Set 5 | mar del plata
# Processing Record 20 of Set 5 | mecca
# Processing Record 21 of Set 5 | mnogovershinnyy
# Processing Record 22 of Set 5 | burnie
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | puerto carreno
# Processing Record 25 of Set 5 | shikarpur
# Processing Record 26 of Set 5 | preobrazheniye
# Processing Record 27 of Set 5 | santa rosa
# Processing Record 28 of Set 5 | dhidhdhoo
# Processing Record 29 of Set 5 | vila franca do campo
# Processing Record 30 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 5 | havre-saint-pierre
# Processing Record 32 of Set 5 | kudahuvadhoo
# Processing Record 33 of Set 5 | bull savanna
# Processing Record 34 of Set 5 | alyangula
# Processing Record 35 of Set 5 | belyy yar
# Processing Record 36 of Set 5 | sakakah
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | chokurdakh
# Processing Record 39 of Set 5 | lysva
# Processing Record 40 of Set 5 | kidal
# Processing Record 41 of Set 5 | ulaangom
# Processing Record 42 of Set 5 | quelimane
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | casambalangan
# Processing Record 45 of Set 5 | tilichiki
# Processing Record 46 of Set 5 | asau
# Processing Record 47 of Set 5 | sooke
# Processing Record 48 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 5 | belmonte
# Processing Record 50 of Set 5 | isangel
# Processing Record 1 of Set 6 | pochutla
# Processing Record 2 of Set 6 | kutum
# Processing Record 3 of Set 6 | flin flon
# Processing Record 4 of Set 6 | ayer tawar
# Processing Record 5 of Set 6 | kualakapuas
# Processing Record 6 of Set 6 | clyde river
# Processing Record 7 of Set 6 | shimodate
# Processing Record 8 of Set 6 | garissa
# Processing Record 9 of Set 6 | conakry
# Processing Record 10 of Set 6 | saqqez
# Processing Record 11 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 6 | russell
# Processing Record 13 of Set 6 | bayamo
# Processing Record 14 of Set 6 | san andres
# Processing Record 15 of Set 6 | umm lajj
# Processing Record 16 of Set 6 | hamburg
# Processing Record 17 of Set 6 | acapulco
# Processing Record 18 of Set 6 | bani walid
# Processing Record 19 of Set 6 | goderich
# Processing Record 20 of Set 6 | riyadh
# Processing Record 21 of Set 6 | nishihara
# Processing Record 22 of Set 6 | valparaiso
# Processing Record 23 of Set 6 | anadyr
# Processing Record 24 of Set 6 | myitkyina
# Processing Record 25 of Set 6 | daru
# Processing Record 26 of Set 6 | college
# Processing Record 27 of Set 6 | mahon
# Processing Record 28 of Set 6 | vardo
# Processing Record 29 of Set 6 | sur
# Processing Record 30 of Set 6 | mana
# Processing Record 31 of Set 6 | sao miguel do araguaia
# Processing Record 32 of Set 6 | coihaique
# Processing Record 33 of Set 6 | mpika
# Processing Record 34 of Set 6 | machinga
# Processing Record 35 of Set 6 | satinka
# Processing Record 36 of Set 6 | ratanpur
# Processing Record 37 of Set 6 | kavarna
# Processing Record 38 of Set 6 | paidha
# Processing Record 39 of Set 6 | koumra
# Processing Record 40 of Set 6 | ilulissat
# Processing Record 41 of Set 6 | paine
# Processing Record 42 of Set 6 | oxapampa
# Processing Record 43 of Set 6 | aykhal
# Processing Record 44 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 6 | half moon bay
# Processing Record 46 of Set 6 | igarka
# Processing Record 47 of Set 6 | tambovka
# Processing Record 48 of Set 6 | ericeira
# Processing Record 49 of Set 6 | mackenzie
# Processing Record 50 of Set 6 | bolshoye nagatkino
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | chapada dos guimaraes
# Processing Record 3 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 7 | richard toll
# City not found. Skipping...
# Processing Record 5 of Set 7 | the pas
# Processing Record 6 of Set 7 | kununurra
# Processing Record 7 of Set 7 | caravelas
# Processing Record 8 of Set 7 | teya
# Processing Record 9 of Set 7 | hinesville
# Processing Record 10 of Set 7 | iskateley
# Processing Record 11 of Set 7 | natitingou
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | karabulak
# Processing Record 14 of Set 7 | berbera
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | liwale
# Processing Record 17 of Set 7 | victoria
# Processing Record 18 of Set 7 | leh
# Processing Record 19 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 20 of Set 7 | luderitz
# Processing Record 21 of Set 7 | cajnice
# Processing Record 22 of Set 7 | sol-iletsk
# Processing Record 23 of Set 7 | wukari
# Processing Record 24 of Set 7 | kasempa
# Processing Record 25 of Set 7 | sisimiut
# Processing Record 26 of Set 7 | kalabo
# Processing Record 27 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 7 | port lincoln
# Processing Record 29 of Set 7 | chara
# Processing Record 30 of Set 7 | sosnovka
# Processing Record 31 of Set 7 | nova odesa
# Processing Record 32 of Set 7 | lima
# Processing Record 33 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 7 | cayenne
# Processing Record 35 of Set 7 | hamilton
# Processing Record 36 of Set 7 | coria
# Processing Record 37 of Set 7 | kotido
# Processing Record 38 of Set 7 | marrakesh
# Processing Record 39 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 7 | charters towers
# Processing Record 41 of Set 7 | patea
# Processing Record 42 of Set 7 | kavieng
# Processing Record 43 of Set 7 | la paz
# Processing Record 44 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 7 | evensk
# Processing Record 46 of Set 7 | jiuquan
# Processing Record 47 of Set 7 | honiara
# Processing Record 48 of Set 7 | mufulira
# Processing Record 49 of Set 7 | bentiu
# Processing Record 50 of Set 7 | yining
# Processing Record 1 of Set 8 | lata
# Processing Record 2 of Set 8 | jambi
# Processing Record 3 of Set 8 | tutoia
# Processing Record 4 of Set 8 | impfondo
# Processing Record 5 of Set 8 | wajir
# Processing Record 6 of Set 8 | mahebourg
# Processing Record 7 of Set 8 | peniche
# Processing Record 8 of Set 8 | stornoway
# Processing Record 9 of Set 8 | nanortalik
# Processing Record 10 of Set 8 | roald
# Processing Record 11 of Set 8 | ponta do sol
# Processing Record 12 of Set 8 | sao gabriel da cachoeira
# Processing Record 13 of Set 8 | yulara
# Processing Record 14 of Set 8 | broome
# Processing Record 15 of Set 8 | plouzane
# Processing Record 16 of Set 8 | salalah
# Processing Record 17 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 18 of Set 8 | betong
# Processing Record 19 of Set 8 | codrington
# Processing Record 20 of Set 8 | saint anthony
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | olot
# Processing Record 23 of Set 8 | hearst
# Processing Record 24 of Set 8 | yasnyy
# Processing Record 25 of Set 8 | la ronge
# Processing Record 26 of Set 8 | iraquara
# Processing Record 27 of Set 8 | gairo
# Processing Record 28 of Set 8 | abu kamal
# Processing Record 29 of Set 8 | qasigiannguit
# Processing Record 30 of Set 8 | canavieiras
# Processing Record 31 of Set 8 | camocim
# Processing Record 32 of Set 8 | samana
# Processing Record 33 of Set 8 | jamui
# Processing Record 34 of Set 8 | sao filipe
# Processing Record 35 of Set 8 | krasnoselkup
# Processing Record 36 of Set 8 | mehamn
# Processing Record 37 of Set 8 | marzuq
# Processing Record 38 of Set 8 | araouane
# Processing Record 39 of Set 8 | nelson bay
# Processing Record 40 of Set 8 | cambridge
# Processing Record 41 of Set 8 | bolshaya irba
# City not found. Skipping...
# Processing Record 42 of Set 8 | grindavik
# Processing Record 43 of Set 8 | conceicao do araguaia
# Processing Record 44 of Set 8 | east london
# Processing Record 45 of Set 8 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 46 of Set 8 | riviera beach
# Processing Record 47 of Set 8 | chaumont
# Processing Record 48 of Set 8 | sinnar
# Processing Record 49 of Set 8 | lovozero
# Processing Record 50 of Set 8 | mizdah
# Processing Record 1 of Set 9 | mirabad
# Processing Record 2 of Set 9 | alofi
# Processing Record 3 of Set 9 | naze
# Processing Record 4 of Set 9 | maniitsoq
# Processing Record 5 of Set 9 | banda aceh
# Processing Record 6 of Set 9 | san roque
# Processing Record 7 of Set 9 | thai binh
# Processing Record 8 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 9 | lakes entrance
# Processing Record 10 of Set 9 | mahibadhoo
# Processing Record 11 of Set 9 | kalevala
# Processing Record 12 of Set 9 | kurilsk
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | borogontsy
# Processing Record 15 of Set 9 | hami
# Processing Record 16 of Set 9 | xai-xai
# Processing Record 17 of Set 9 | sao sebastiao
# Processing Record 18 of Set 9 | saldanha
# Processing Record 19 of Set 9 | bathsheba
# Processing Record 20 of Set 9 | boffa
# Processing Record 21 of Set 9 | alta floresta
# Processing Record 22 of Set 9 | panzhihua
# Processing Record 23 of Set 9 | mokrousovo
# Processing Record 24 of Set 9 | zyryanka
# Processing Record 25 of Set 9 | nerchinskiy zavod
# Processing Record 26 of Set 9 | weinan
# Processing Record 27 of Set 9 | moose factory
# Processing Record 28 of Set 9 | maraa
# Processing Record 29 of Set 9 | san carlos de bariloche
# Processing Record 30 of Set 9 | samarai
# Processing Record 31 of Set 9 | pimentel
# Processing Record 32 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 9 | inirida
# Processing Record 34 of Set 9 | yabrud
# Processing Record 35 of Set 9 | praia da vitoria
# Processing Record 36 of Set 9 | rincon
# Processing Record 37 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 9 | caceres
# Processing Record 39 of Set 9 | balkanabat
# Processing Record 40 of Set 9 | road town
# Processing Record 41 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 9 | buala
# Processing Record 43 of Set 9 | manta
# Processing Record 44 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 45 of Set 9 | sola
# Processing Record 46 of Set 9 | winsum
# Processing Record 47 of Set 9 | verkhnyaya inta
# Processing Record 48 of Set 9 | makakilo city
# Processing Record 49 of Set 9 | luganville
# Processing Record 50 of Set 9 | santa lucia
# Processing Record 1 of Set 10 | bohodukhiv
# Processing Record 2 of Set 10 | maragogi
# Processing Record 3 of Set 10 | faya
# Processing Record 4 of Set 10 | cap malheureux
# Processing Record 5 of Set 10 | port macquarie
# Processing Record 6 of Set 10 | mubi
# Processing Record 7 of Set 10 | anapskaya
# Processing Record 8 of Set 10 | elat
# Processing Record 9 of Set 10 | sorland
# Processing Record 10 of Set 10 | paamiut
# Processing Record 11 of Set 10 | baykit
# Processing Record 12 of Set 10 | taphan hin
# Processing Record 13 of Set 10 | miacatlan
# Processing Record 14 of Set 10 | manggar
# Processing Record 15 of Set 10 | hammerfest
# Processing Record 16 of Set 10 | ola
# Processing Record 17 of Set 10 | arman
# Processing Record 18 of Set 10 | palkino
# Processing Record 19 of Set 10 | suntar
# Processing Record 20 of Set 10 | sri aman
# Processing Record 21 of Set 10 | puerto del rosario
# Processing Record 22 of Set 10 | petatlan
# Processing Record 23 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 10 | ures
# Processing Record 25 of Set 10 | kohat
# Processing Record 26 of Set 10 | ushtobe
# Processing Record 27 of Set 10 | cabedelo
# Processing Record 28 of Set 10 | otane
# Processing Record 29 of Set 10 | bilma
# Processing Record 30 of Set 10 | iberia
# Processing Record 31 of Set 10 | kahului
# Processing Record 32 of Set 10 | celestun
# Processing Record 33 of Set 10 | beyneu
# Processing Record 34 of Set 10 | ponta delgada
# Processing Record 35 of Set 10 | clifton
# Processing Record 36 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 37 of Set 10 | lebedinyy
# Processing Record 38 of Set 10 | houma
# Processing Record 39 of Set 10 | reconquista
# Processing Record 40 of Set 10 | mehran
# Processing Record 41 of Set 10 | tamworth
# Processing Record 42 of Set 10 | atasu
# Processing Record 43 of Set 10 | zhob
# Processing Record 44 of Set 10 | amalapuram
# Processing Record 45 of Set 10 | san juan
# Processing Record 46 of Set 10 | padang
# Processing Record 47 of Set 10 | esso
# Processing Record 48 of Set 10 | xushan
# Processing Record 49 of Set 10 | esmeraldas
# Processing Record 50 of Set 10 | henties bay
# Processing Record 1 of Set 11 | chihuahua
# Processing Record 2 of Set 11 | cabo san lucas
# Processing Record 3 of Set 11 | xuddur
# Processing Record 4 of Set 11 | creel
# Processing Record 5 of Set 11 | oranjemund
# Processing Record 6 of Set 11 | eirunepe
# Processing Record 7 of Set 11 | kaitangata
# Processing Record 8 of Set 11 | ribeira brava
# Processing Record 9 of Set 11 | stromness
# Processing Record 10 of Set 11 | oktyabrskiy
# Processing Record 11 of Set 11 | concarneau
# Processing Record 12 of Set 11 | george town
# Processing Record 13 of Set 11 | inongo
# Processing Record 14 of Set 11 | sumter
# Processing Record 15 of Set 11 | axim
# Processing Record 16 of Set 11 | samfya
# Processing Record 17 of Set 11 | nantucket
# Processing Record 18 of Set 11 | olga
# Processing Record 19 of Set 11 | ventspils
# Processing Record 20 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | gazanjyk
# Processing Record 22 of Set 11 | puerto escondido
# Processing Record 23 of Set 11 | obo
# Processing Record 24 of Set 11 | kenai
# Processing Record 25 of Set 11 | nouakchott
# Processing Record 26 of Set 11 | we
# City not found. Skipping...
# Processing Record 27 of Set 11 | sao joao da barra
# Processing Record 28 of Set 11 | macon
# Processing Record 29 of Set 11 | moron
# Processing Record 30 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 11 | halifax
# Processing Record 32 of Set 11 | ellisras
# Processing Record 33 of Set 11 | wilmington
# Processing Record 34 of Set 11 | whitehorse
# Processing Record 35 of Set 11 | kamaishi
# Processing Record 36 of Set 11 | san jose poaquil
# Processing Record 37 of Set 11 | laguna
# Processing Record 38 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 11 | bay roberts
# Processing Record 40 of Set 11 | mbacke
# City not found. Skipping...
# Processing Record 41 of Set 11 | remedios
# Processing Record 42 of Set 11 | awjilah
# Processing Record 43 of Set 11 | ambilobe
# Processing Record 44 of Set 11 | otrado-olginskoye
# Processing Record 45 of Set 11 | high level
# Processing Record 46 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 11 | svetlaya
# Processing Record 49 of Set 11 | nioki
# Processing Record 50 of Set 11 | katherine
# Processing Record 1 of Set 12 | hailey
# Processing Record 2 of Set 12 | griffith
# Processing Record 3 of Set 12 | kokstad
# Processing Record 4 of Set 12 | moranbah
# Processing Record 5 of Set 12 | udachnyy
# Processing Record 6 of Set 12 | port hedland
# Processing Record 7 of Set 12 | bafq
# Processing Record 8 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 12 | palu
# Processing Record 10 of Set 12 | ixtapa
# Processing Record 11 of Set 12 | istok
# Processing Record 12 of Set 12 | walvis bay
# Processing Record 13 of Set 12 | xiongzhou
# Processing Record 14 of Set 12 | moree
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | vadinsk
# Processing Record 17 of Set 12 | paso de carrasco
# Processing Record 18 of Set 12 | poum
# Processing Record 19 of Set 12 | dunedin
# Processing Record 20 of Set 12 | buluang
# Processing Record 21 of Set 12 | catuday
# Processing Record 22 of Set 12 | stokmarknes
# Processing Record 23 of Set 12 | talnakh
# Processing Record 24 of Set 12 | brae
# Processing Record 25 of Set 12 | surt
# Processing Record 26 of Set 12 | la palma
# Processing Record 27 of Set 12 | okhotsk
# Processing Record 28 of Set 12 | la romana
# Processing Record 29 of Set 12 | sitka
# Processing Record 30 of Set 12 | astoria
# Processing Record 31 of Set 12 | zhigansk
# Processing Record 32 of Set 12 | grootfontein
# Processing Record 33 of Set 12 | voh
# Processing Record 34 of Set 12 | newport
# Processing Record 35 of Set 12 | lashio
# Processing Record 36 of Set 12 | bulgan
# Processing Record 37 of Set 12 | pozo colorado
# Processing Record 38 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 39 of Set 12 | narsaq
# Processing Record 40 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 12 | tabat
# Processing Record 42 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 12 | montague
# Processing Record 44 of Set 12 | eyl
# Processing Record 45 of Set 12 | polunochnoye
# Processing Record 46 of Set 12 | bubaque
# Processing Record 47 of Set 12 | tagusao
# Processing Record 48 of Set 12 | worthing
# Processing Record 49 of Set 12 | providencia
# Processing Record 50 of Set 12 | portland
# Processing Record 1 of Set 13 | ongole
# Processing Record 2 of Set 13 | coolum beach
# Processing Record 3 of Set 13 | salamiyah
# Processing Record 4 of Set 13 | saint-michel-des-saints
# Processing Record 5 of Set 13 | bilibino
# Processing Record 6 of Set 13 | denpasar
# Processing Record 7 of Set 13 | sambava
# Processing Record 8 of Set 13 | fairbanks
# Processing Record 9 of Set 13 | kirovsk
# Processing Record 10 of Set 13 | northam
# Processing Record 11 of Set 13 | bosaso
# Processing Record 12 of Set 13 | fuerte olimpo
# Processing Record 13 of Set 13 | kieta
# Processing Record 14 of Set 13 | marawi
# Processing Record 15 of Set 13 | colesberg
# Processing Record 16 of Set 13 | druzhba
# Processing Record 17 of Set 13 | cuamba
# Processing Record 18 of Set 13 | xining
# Processing Record 19 of Set 13 | manicore
# Processing Record 20 of Set 13 | abu samrah
# Processing Record 21 of Set 13 | tondano
# Processing Record 22 of Set 13 | la rioja
# Processing Record 23 of Set 13 | tigil
# Processing Record 24 of Set 13 | yuyao
# Processing Record 25 of Set 13 | mayumba
# Processing Record 26 of Set 13 | forssa
# Processing Record 27 of Set 13 | lasa
# Processing Record 28 of Set 13 | iwanai
# Processing Record 29 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 13 | tual
# Processing Record 31 of Set 13 | lae
# Processing Record 32 of Set 13 | haines city
# Processing Record 33 of Set 13 | alassio
# Processing Record 34 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 13 | brawley
# Processing Record 36 of Set 13 | alvaraes
# Processing Record 37 of Set 13 | mezhova
# Processing Record 38 of Set 13 | hilton head island
# Processing Record 39 of Set 13 | namatanai
# Processing Record 40 of Set 13 | manono
# Processing Record 41 of Set 13 | hokitika
# Processing Record 42 of Set 13 | cooma
# Processing Record 43 of Set 13 | port augusta
# Processing Record 44 of Set 13 | twin falls
# Processing Record 45 of Set 13 | cuxhaven
# Processing Record 46 of Set 13 | krasnaya gorka
# Processing Record 47 of Set 13 | diamantino
# Processing Record 48 of Set 13 | urgut
# Processing Record 49 of Set 13 | kysyl-syr
# Processing Record 50 of Set 13 | ketchikan
# Processing Record 1 of Set 14 | nueve de julio
# Processing Record 2 of Set 14 | belaya gora
# Processing Record 3 of Set 14 | kabinda
# Processing Record 4 of Set 14 | margate
# Processing Record 5 of Set 14 | saint-georges
# Processing Record 6 of Set 14 | woodward
# Processing Record 7 of Set 14 | coquimbo
# Processing Record 8 of Set 14 | chandil
# Processing Record 9 of Set 14 | bundaberg
# Processing Record 10 of Set 14 | tucuman
# Processing Record 11 of Set 14 | bintulu
# Processing Record 12 of Set 14 | beatrice
# Processing Record 13 of Set 14 | hovd
# Processing Record 14 of Set 14 | shitanjing
# Processing Record 15 of Set 14 | myanaung
# Processing Record 16 of Set 14 | sibolga
# Processing Record 17 of Set 14 | burica
# City not found. Skipping...
# Processing Record 18 of Set 14 | shache
# Processing Record 19 of Set 14 | cabinda
# Processing Record 20 of Set 14 | stende
# Processing Record 21 of Set 14 | darlawn
# Processing Record 22 of Set 14 | jijiga
# Processing Record 23 of Set 14 | shelburne
# Processing Record 24 of Set 14 | matagami
# Processing Record 25 of Set 14 | weymouth
# Processing Record 26 of Set 14 | camiri
# Processing Record 27 of Set 14 | shahreza
# Processing Record 28 of Set 14 | muisne
# Processing Record 29 of Set 14 | deder
# Processing Record 30 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 14 | tha chang
# Processing Record 32 of Set 14 | huilong
# Processing Record 33 of Set 14 | auki
# Processing Record 34 of Set 14 | serenje
# Processing Record 35 of Set 14 | kaiyuan
# Processing Record 36 of Set 14 | tirat karmel
# Processing Record 37 of Set 14 | milkovo
# Processing Record 38 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 14 | christchurch
# Processing Record 40 of Set 14 | ilheus
# Processing Record 41 of Set 14 | chifeng
# Processing Record 42 of Set 14 | kemise
# Processing Record 43 of Set 14 | mancio lima
# Processing Record 44 of Set 14 | mahajanga
# Processing Record 45 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 14 | fomboni
# Processing Record 47 of Set 14 | rawson
# Processing Record 48 of Set 14 | vrangel
# Processing Record 49 of Set 14 | denau
# City not found. Skipping...
# Processing Record 50 of Set 14 | ilhabela
# Processing Record 1 of Set 15 | buzmeyin
# Processing Record 2 of Set 15 | pangody
# Processing Record 3 of Set 15 | khipro
# Processing Record 4 of Set 15 | syamzha
# Processing Record 5 of Set 15 | zhuanghe
# Processing Record 6 of Set 15 | itupiranga
# Processing Record 7 of Set 15 | ribas do rio pardo
# Processing Record 8 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 15 | mogocha
# Processing Record 10 of Set 15 | kudat
# Processing Record 11 of Set 15 | gannan
# Processing Record 12 of Set 15 | zhezkazgan
# Processing Record 13 of Set 15 | maturin
# Processing Record 14 of Set 15 | huron
# Processing Record 15 of Set 15 | martinsville
# Processing Record 16 of Set 15 | hay river
# Processing Record 17 of Set 15 | diamantina
# Processing Record 18 of Set 15 | juneau
# Processing Record 19 of Set 15 | narasannapeta
# Processing Record 20 of Set 15 | caracoli
# Processing Record 21 of Set 15 | killarney
# Processing Record 22 of Set 15 | huangnihe
# Processing Record 23 of Set 15 | mandalgovi
# Processing Record 24 of Set 15 | namwala
# Processing Record 25 of Set 15 | tateyama
# Processing Record 26 of Set 15 | huarmey
# Processing Record 27 of Set 15 | samdari
# Processing Record 28 of Set 15 | ninghai
# Processing Record 29 of Set 15 | cristalina
# Processing Record 30 of Set 15 | namtsy
# Processing Record 31 of Set 15 | nikolayevka
# Processing Record 32 of Set 15 | menongue
# Processing Record 33 of Set 15 | san lucas
# Processing Record 34 of Set 15 | defiance
# Processing Record 35 of Set 15 | bedele
# Processing Record 36 of Set 15 | sikeston
# Processing Record 37 of Set 15 | mugla
# Processing Record 38 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 15 | inhambane
# Processing Record 40 of Set 15 | vagur
# Processing Record 41 of Set 15 | longonjo
# Processing Record 42 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 15 | port-gentil
# Processing Record 44 of Set 15 | torit
# Processing Record 45 of Set 15 | alice springs
# Processing Record 46 of Set 15 | nur
# Processing Record 47 of Set 15 | vierzon
# Processing Record 48 of Set 15 | craig
# Processing Record 49 of Set 15 | patamundai
# Processing Record 50 of Set 15 | olean
# Processing Record 1 of Set 16 | amuntai
# Processing Record 2 of Set 16 | urengoy
# Processing Record 3 of Set 16 | bonavista
# Processing Record 4 of Set 16 | collie
# Processing Record 5 of Set 16 | mengcheng
# Processing Record 6 of Set 16 | aksu
# Processing Record 7 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 16 | kavaratti
# Processing Record 9 of Set 16 | dalnegorsk
# Processing Record 10 of Set 16 | fraserburgh
# Processing Record 11 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 16 | amahai
# Processing Record 13 of Set 16 | pitimbu
# Processing Record 14 of Set 16 | pout
# Processing Record 15 of Set 16 | praia
# Processing Record 16 of Set 16 | champerico
# Processing Record 17 of Set 16 | shimanovsk
# Processing Record 18 of Set 16 | venado tuerto
# Processing Record 19 of Set 16 | nara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Blair  11.6667   92.7500     77.04        94          40
# 1  Puerto Ayora  -0.7393  -90.3518     84.16        89          74
# 2   Port Alfred -33.5906   26.8910     71.19        95         100
# 3      Khatanga  71.9667  102.5000     -8.39        98         100
# 4       Mataura -46.1927  168.8643     55.47        92          99
# 5         Dakar  14.6937  -17.4441     79.68        83           0
# 6     Tuatapere -46.1333  167.6833     54.30        93          99
# 7       Itarema  -2.9248  -39.9167     81.70        72           5
# 8     Mapiripan   2.8892  -72.1256     84.31        65          96
# 9  Khudumelapye -23.8833   24.7500     75.38        46          24
#
#    Wind Speed Country Weather Desc                 Date
# 0        0.00      IN         Mist  2022-12-10 19:56:49
# 1        5.01      EC       Clouds  2022-12-10 19:56:50
# 2        1.01      ZA         Rain  2022-12-10 19:56:50
# 3       11.07      RU       Clouds  2022-12-10 19:56:50
# 4        1.07      NZ       Clouds  2022-12-10 19:56:51
# 5        4.61      SN        Clear  2022-12-10 19:56:51
# 6        3.00      NZ       Clouds  2022-12-10 19:56:51
# 7       17.63      BR        Clear  2022-12-10 19:56:52
# 8        5.14      CO       Clouds  2022-12-10 19:56:52
# 9        7.54      BW       Clouds  2022-12-10 19:56:52

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Desc', 'Date'],
#       dtype='object')

# %%
city_data_df.rename(columns={'Weather Desc':'Current Description'}, inplace=True)

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Blair      IN  11.6667   92.7500     77.04        94          40
# 1  Puerto Ayora      EC  -0.7393  -90.3518     84.16        89          74
# 2   Port Alfred      ZA -33.5906   26.8910     71.19        95         100
# 3      Khatanga      RU  71.9667  102.5000     -8.39        98         100
# 4       Mataura      NZ -46.1927  168.8643     55.47        92          99
#
#    Wind Speed Current Description
# 0        0.00                Mist
# 1        5.01              Clouds
# 2        1.01                Rain
# 3       11.07              Clouds
# 4        1.07              Clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
